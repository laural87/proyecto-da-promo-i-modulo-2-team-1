# %% [markdown]
# # Fase 2

# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
from selenium.webdriver.common.keys import Keys  
from selenium.webdriver.support.ui import Select 

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep

# %% [markdown]
# # Código para cargar y concatenar los resultados de las extracciones de la Fase 1

# %%
# Trasladar todas las tuplas del diccionario a una sola lista
# Paso 1: guardar datos de cada extracción en variables 

extracion_maira = pd.read_json('CSV_JSON_F1/datos_filtrados_2010_2024.json')
extracion_yami = pd.read_json('CSV_JSON_F1/datos_filtrados_Yami_2010_2024.json')
extracion_carolina = pd.read_json('CSV_JSON_F1/datos_filtrados_2010_2024_carolina.json')
extracion_laura = pd.read_json('CSV_JSON_F1/datos_filtrados_2010_2024_laura.json')

# %%
# Paso 2: Creamos una función para iterar por cada variable para guardar los datos en listas de tuplas

def itera_variables(extracion):
    anios = [i for i in range(2010, 2025)]
    generos = ['Action', 'Comedy', 'Drama']
    resultados_tuplas = []

    for anio in anios:
        for genero in generos:
            for tupla in extracion[anio][genero]:
                resultados_tuplas.append(tuple(tupla))

    return resultados_tuplas

# %%
# Concatenamos todas las listas
resultado_tuplas_total = itera_variables(extracion_maira) + itera_variables(extracion_yami) + itera_variables(extracion_carolina) + itera_variables(extracion_laura)

# %%
len(resultado_tuplas_total)
# Out:
# 17395

# %%
resultado_tuplas_total[:10]
# Out:
# [('Movie', 'Tekken', 2010, 3, 'tt0411951'),
#  ('Movie', 'Venus & Vegas', 2010, 11, 'tt0423474'),
#  ('Movie', 'The A-Team', 2010, 6, 'tt0429493'),
#  ('Movie', 'Segurança Nacional', 2010, 5, 'tt0439801'),
#  ('Movie', 'Scott Pilgrim vs. the World', 2010, 11, 'tt0446029'),
#  ('Movie', 'Taken by Force', 2010, None, 'tt0465637'),
#  ('Movie', 'Guns, Drugs and Dirty Money', 2011, None, 'tt0464032'),
#  ('Movie', 'Komaram Puli', 2010, 9, 'tt0464162'),
#  ('Movie', 'Prince of Persia: The Sands of Time', 2010, 5, 'tt0473075'),
#  ('Movie', 'Unstoppable', 2010, 12, 'tt0477080')]

# %%
# Verificar que no haya elementos repetidos
# Crear un conjunto vacío
elementos_vistos = set()

# Verificar duplicados
contador = 0
for elemento in resultado_tuplas_total:
    if elemento in elementos_vistos:
        contador += 1
        resultado_tuplas_total.remove(elemento)
    elementos_vistos.add(elemento)
    
print(f"Se ha encontrado {contador} elementos repetidos")
print(f"Tras remover las tuplas repetidas, nuestra lista se quedó con {len(resultado_tuplas_total)} elementos.")
# Out:
# Se ha encontrado 2401 elementos repetidos
# Tras remover las tuplas repetidas, nuestra lista se quedó con 14994 elementos.

# %%
# Guardar lista final de manera permanente
df_final = pd.DataFrame(resultado_tuplas_total)
df_final[2] = df_final[2].astype('Int64')
df_final[3] = df_final[3].astype('Int64')
df_final.to_csv('resultado_tuplas_total.csv', index=False)
df_final.to_json('resultado_tuplas_total.json')

# %% [markdown]
# # Código para recuperar la lista final de tuplas

# %%
resultado_tuplas_total = pd.read_csv('resultado_tuplas_total.csv', header=None) # Ejecutar a partir de aquí

# %%
resultado_tuplas_total = [tuple(fila) for fila in resultado_tuplas_total.values]
resultado_tuplas_total = resultado_tuplas_total[1:]

# %%
len(resultado_tuplas_total)
# Out:
# 14994

# %%
for peli in resultado_tuplas_total[2911:2912]: # Prueba: Iterando para extraer el id_imdb y el nombre 
    id_imdb = peli[-1]
    nombre = peli[1]
    print(id_imdb)
    print(nombre)
# Out:
# tt18797620
# Murdock by day

# %%
search_tomato = id_imdb + ' ' + nombre + ' ' + 'tomatometer' # Creación de una variable con el contenido de la búsqueda para Rotten Tomatoes
search_tomato
# Out:
# 'tt18797620 Murdock by day tomatometer'

# %%
# Creación de la variables que vamos a usar en la extración con Selenium
url_imdb = "https://www.imdb.com/"
url_rotten = "https://www.rottentomatoes.com/"
url_google = 'https://www.google.com/'
selector_cookies_imdb = "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd"
selector_cookies_google = "#L2AGLb > div"

# %%
# Creacción de las listas donde vamos a almacenar los resultados de la extración.
resultados_completos = []
resultados_sin_tomatometer = []
not_found = []

# %%
# Creamos una función para abrir los navegadores 
def abrir_navegador(driver, url, selector):
    driver = webdriver.Chrome() # Inicializa el navegador Chrome
    sleep(3)
    driver.maximize_window() # Maximiza la ventana
    driver.get(url) # Navega a la url pasada por parámetro
    sleep(3)
    try:
        driver.find_element("css selector", selector).click() # Intentamos aceptar las cookies
        sleep(3)
    except: # Si salta error, imprime un mensaje avisando.
        print("No ha sido posible aceptar las cookies, puede que no saltó el aviso o que se haya cambiado el selector.")
    
    return driver # retorna el driver que será usado para las demás tareas

# %%
# Creamos listas con selectores css para hacer iteraciones
selector_imdb_rating = ["#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-3a4309f8-0.bjXIAP.sc-1f50b7c-1.bfrqUc > div > div:nth-child(1) > a > span > div > div.sc-eb51e184-0.kFvAju > div.sc-eb51e184-2.czkfBq > span.sc-eb51e184-1.cxhhrI"]
selector_direccion = ["#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(1) > div > ul > li > a", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(1) > div > ul > li > a"]
selector_guionista = ["#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul > li > a", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.sc-1f50b7c-3.ZYFjc > div > ul > li:nth-child(2) > div > ul"]
selector_argumento = ["#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > p > span.sc-2d37a7c7-2.PeLXr", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > p > span.sc-2d37a7c7-2.PeLXr"]
selector_duracion = ["#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > ul > li:nth-child(3)", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > ul > li:nth-child(2)"]
selector_nombre = ["#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > h1 > span"," #__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-3.bdjVSf > div.sc-1f50b7c-0.PUxFE > h1 > span"]
selector_genero = ["#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.yjUiO > div.sc-491663c0-6.lnlBxO > div.sc-491663c0-10.rbXFE > section > div.ipc-chip-list--baseAlt.ipc-chip-list.ipc-chip-list--nowrap.sc-2d37a7c7-4.kEPwNU > div.ipc-chip-list__scroller", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-10.emoxHI > section > div.ipc-chip-list--baseAlt.ipc-chip-list.ipc-chip-list--nowrap.sc-2d37a7c7-4.kEPwNU > div.ipc-chip-list__scroller > a"]
selector_primer_result_ggle = ["#rso > div:nth-child(1) > div > div > div.kb0PBd.cvP2Ce.A9Y9g.jGGQ5e > div > div > span > a > h3", "#rso > div.MjjYud > div > div > div.kb0PBd.cvP2Ce.A9Y9g.jGGQ5e > div > div > span > a > h3","#rso > div:nth-child(1) > div > div > div > div.kb0PBd.cvP2Ce.A9Y9g.jGGQ5e > div > div > span > a > h3"]
selector_tomatometer = ["#modules-wrap > div.media-scorecard.no-border > media-scorecard > rt-button:nth-child(3) > rt-text", "#rso > div.MjjYud > div > div > div.kb0PBd.cvP2Ce.A9Y9g.jGGQ5e > div > div > span > a > h3", "#rso > div:nth-child(1) > div > div > div.kb0PBd.cvP2Ce.A9Y9g.jGGQ5e > div > div > span > a > h3"]

# %%
# Creamos una función para iterar por los selectores haciendo los try except parsa extraer datos de imdb
def extrae_datos(lista_selector, driver, id_imdb=id_imdb, nombre=nombre):
    for selector in lista_selector:
        try:
            dato = driver.find_element("css selector", selector).text
            sleep(3)
            return dato 
        except Exception as e:
            excepcion = e

    error = f"Faltan datos de imdb para la peli: {nombre} id_imdb: {id_imdb}, error de tipo: {excepcion}."
    not_found.append(error)
    dato = None
    return dato

# %%
# Creamos una función para pinchar en el primer resultado de google
def clica_primer_result_ggle(lista_selector, driver, id_imdb, nombre):

    if id_imdb is None:
        error = "El id_imdb no puede ser None"
        not_found.append(error)
        return False
    
    if nombre is None:
        error = "El nombre no puede ser None"
        not_found.append(error)
        return False
    
    search_tomato = id_imdb + ' ' + nombre + ' ' + 'tomatometer'

    try:
        driver.find_element("css selector", "#APjFqb").send_keys(search_tomato, Keys.ENTER) # Pasamos el string al buscador de google
        sleep(5)
    except Exception as e:
        error = f"Error al buscar en Google para la peli {nombre} con id_imdb {id_imdb}, error de tipo: {e}."
        not_found.append(error)
        return False
    
    for selector in lista_selector:
        try:                                
            sleep(5)                            
            driver.find_element("css selector", selector).click() # Pinchamos en el primer resultado de la búsqueda de google
            sleep(4)
            return True
        except Exception as e:
            excepcion = e
    
    error = f"No hay tomatometer para la peli {nombre} con id_imdb {id_imdb}, error de tipo: {excepcion}."
    not_found.append(error)
    driver.back()
    sleep(3)
    return False

# %%
# Creamos una función para aceptar cookies en el navegador de google
def acepta_cookies(driver, on_off):
    try:
        if on_off:
            driver.find_element("css selector", "#onetrust-accept-btn-handler").click() # Acepta cookies
            on_off = False
            sleep(2)
    except:
        pass
        # print("No hemos clicado en el aviso de cookies de google: No hubo aviso, el selector ha cambiado o no hubo tiempo suficiente para terminar de cargar la página.")

# %%
# Creamos una función para extraer el tomatometer
def extrae_tomato(lista_selector, driver, id_imdb, nombre):
    for selector in lista_selector:
        try:                                                   
            tomatometer = driver.find_element("css selector", selector).text # Extrae el Rating tomatometer
            sleep(3)
            driver.back()
            sleep(3)
            driver.back()
            sleep(3)
            return tomatometer
        except Exception as e:
            excepcion = e
            
    tomatometer = None
    error = f"No hay tomatometer para la peli {nombre} con id_imdb {id_imdb}, error de tipo: {excepcion}."
    not_found.append(error)
    driver.back()
    sleep(3)
    driver.back()
    sleep(3)
    return tomatometer

# %%
# Llamamos a todas las funciones para extraer los datos

driver1 = None
driver1 = abrir_navegador(driver1, url_imdb, selector_cookies_imdb)

driver2 = None
driver2 = abrir_navegador(driver2, url_google, selector_cookies_google)

contador = 0 # Creamos un contador para saber por que iteración vamos
on_off = True # Creamos un botón de on off para pasar el valor a la función acepta_cookies

'''
Maíra: 0:50, 200:400 ok, next = 400:1000
Yami: 50:100 
Laura: 100:150 ok, next = 1000:2000 next 2400-2600 next 2600-3000 next 3000 -3500
Carolina: 150:200
'''

# Iterar por los ids_imdbs para pasarlos por el campo search de la web de imdb:
for peli in resultado_tuplas_total[3000:3500]:
    id_imdb = peli[-1]
    nombre = peli[1]
    try:
        # Pasamos el id_imdb al buscador de imdb
        driver1.find_element("css selector", "#suggestion-search").send_keys(id_imdb, Keys.ENTER)
        sleep(5)

        # Extraímos los datos de imdb
        imdb_rating = extrae_datos(selector_imdb_rating, driver1)
        direccion = extrae_datos(selector_direccion, driver1)
        guionista = extrae_datos(selector_guionista, driver1)
        argumento = extrae_datos(selector_argumento, driver1)
        genero = extrae_datos(selector_genero, driver1)
        duracion = extrae_datos(selector_duracion, driver1)
        nombre = extrae_datos(selector_nombre, driver1)

        # Extraímos el tomatometer
        pinchar_google = clica_primer_result_ggle(selector_primer_result_ggle, driver2, id_imdb, nombre)
        if pinchar_google:
            acepta_cookies(driver2, on_off)
            tomatometer = extrae_tomato(selector_tomatometer, driver2, id_imdb, nombre)
        else:
            tomatometer = None
            
        # Creamos la tupla y la añadimos a la lista que corresponda (completa o sin tomatometer)
        if tomatometer:
            tupla = imdb_rating, tomatometer, direccion, guionista, argumento, genero, duracion, nombre
            if None in tupla:
                contador += 1
                print(f"La tupla de la peli {nombre} no está completa: {tupla} Vamos por la iteración: {contador}")
            else:
                resultados_completos.append(tupla)
                contador += 1
                print(f"Hemos añadido la peli {nombre} a la lista completa. Vamos por la iteración: {contador}.")
        else:
            tupla = imdb_rating, direccion, guionista, argumento, genero, duracion, nombre
            if None in tupla:
                contador += 1
                print(f"La tupla de la peli {nombre} no está completa: {tupla} Vamos por la iteración: {contador}")
            else:
                tupla = imdb_rating, tomatometer, direccion, guionista, argumento, genero, duracion, nombre
                resultados_sin_tomatometer.append(tupla)
                contador += 1
                print(f"Hemos añadido la peli {nombre} a la lista sin tomatometer. Vamos por la iteración: {contador}.")
    except Exception as e:
            excepcion = e
            contador += 1
            print(f"No se encontró el elemento de búsqueda para la película {nombre} con ID {id_imdb}.Vamos por la iteración: {contador}.")
            driver1.back()
            sleep(5)
            continue

driver1.close()
driver2.close()
# Out:
# Hemos añadido la peli Dungeons & Dragons: Honor entre ladrones a la lista completa. Vamos por la iteración: 1.
# Hemos añadido la peli Una pequeña mentira a la lista sin tomatometer. Vamos por la iteración: 2.
# La tupla de la peli The Hard Time Zoo no está completa: (None, 'Ricardo Colon', 'Ricardo Colon', 'A meteorite strike alters the intelligence of all the earth\'s land-bound animals giving them the ability to THINK and SPEAK as humans. World governments react by forcing the animals into a special facility that the PUBLIC believes to be are animal detainment centers called "ZOOs".', 'Animación', '1h 15min', 'The Hard Time Zoo') Vamos por la iteración: 3
# Hemos añadido la peli Wonka a la lista sin tomatometer. Vamos por la iteración: 4.
# Hemos añadido la peli Migración: Un viaje patas arriba a la lista completa. Vamos por la iteración: 5.
# Hemos añadido la peli Super Mario Bros.: La película a la lista completa. Vamos por la iteración: 6.
# La tupla de la peli With an Open Heart no está completa: (None, None, None, None, None, None, 'With an Open Heart') Vamos por la iteración: 7
# La tupla de la peli Lost Weekend no está completa: (None, '88%', 'Frank Coraci', 'Benjamin Sutor', 'His marriage and band falling apart, John Lennon recruits comedian Albert Brooks and musician Harry Nilsson for a raucous 24-hour journey through 1973 Los Angeles to try to save a lost album and himself.', 'Comedia', None, 'Lost Weekend') Vamos por la iteración: 8
# La tupla de la peli Old Man Jackson no está completa: ('8,6', 'Johnny Ray Gibbs', 'Johnny Ray Gibbs', 'El Sr. Jackson, propietario de un taller de mecánica automotriz galardonado e hipocondríaco muy nervioso, tiene una premonición. Sin hijos propios que puedan transmitir el legado que su abuelo inició, tiene una última misión que cumplir.', 'Comedia', None, 'Old Man Jackson') Vamos por la iteración: 9
# La tupla de la peli Bear Trap no está completa: (None, 'Danene Montella', 'Jacob ChattmanDanene Montella', "A woman struggling to cook mirepoix for the first time flies off the handle when her clueless boyfriend suggests attending his ex-girlfriend's birthday party.", 'Corto', None, 'Bear Trap') Vamos por la iteración: 10
# Hemos añadido la peli Cheburashka a la lista sin tomatometer. Vamos por la iteración: 11.
# Hemos añadido la peli House Party a la lista completa. Vamos por la iteración: 12.
# La tupla de la peli Untitled Holiday Comedy no está completa: (None, None, None, None, None, None, 'Untitled Holiday Comedy') Vamos por la iteración: 13
# Hemos añadido la peli Guardianes de la Galaxia Vol. 3 a la lista sin tomatometer. Vamos por la iteración: 14.
# Hemos añadido la peli Skimbagirls a la lista sin tomatometer. Vamos por la iteración: 15.
# La tupla de la peli South B.Boys, Volando en el Suelo no está completa: (None, 'Mario Lobo', 'Mauel AcuñaDaniel GómezPablo Ortíz', '', 'Comedia', None, 'South B.Boys, Volando en el Suelo') Vamos por la iteración: 16
# Hemos añadido la peli Mentira o astucia a la lista sin tomatometer. Vamos por la iteración: 17.
# Hemos añadido la peli Ninja Turtles: Caos mutante a la lista sin tomatometer. Vamos por la iteración: 18.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 19
# No se encontró el elemento de búsqueda para la película Hidden Strike con ID tt6879446.Vamos por la iteración: 20.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 21
# No se encontró el elemento de búsqueda para la película Asfixiados con ID tt16969060.Vamos por la iteración: 22.
# La tupla de la peli Bilan de santé no está completa: (None, 'Tommy Harvey', 'Tommy Harvey', '', 'Corto', '10min', 'Bilan de santé') Vamos por la iteración: 23
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 24
# No se encontró el elemento de búsqueda para la película Deli Meat con ID tt17066254.Vamos por la iteración: 25.
# La tupla de la peli Bigfoot Kills: A True Crime Documentary no está completa: (None, 'Robert Pierce', 'A.J. Laird', "Three online bloggers vanished over the summer of 2013 in Wisconsin's isolated woodlands. This video was their final recording.", 'Comedia\nCrimen', None, 'Bigfoot Kills: A True Crime Documentary') Vamos por la iteración: 26
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 27
# No se encontró el elemento de búsqueda para la película Lethal Love con ID tt17421824.Vamos por la iteración: 28.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 29
# No se encontró el elemento de búsqueda para la película Varsity Squad con ID tt17489070.Vamos por la iteración: 30.
# Hemos añadido la peli Meter i sekundet a la lista sin tomatometer. Vamos por la iteración: 31.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 32
# No se encontró el elemento de búsqueda para la película The Last Video Store con ID tt17423262.Vamos por la iteración: 33.
# La tupla de la peli Atrabilious no está completa: (None, '100%', 'William Atticus Parker', 'William Atticus Parker', "Atrabilious follows Steven Joyner as he tries to solve the mystery behind his son's sudden, tragic and potentially fabricated death.", 'Comedia', None, 'Atrabilious') Vamos por la iteración: 34
# La tupla de la peli Sexy Nails by Aunt Tootsie no está completa: (None, None, None, None, None, None, 'Sexy Nails by Aunt Tootsie') Vamos por la iteración: 35
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 36
# No se encontró el elemento de búsqueda para la película Illusions con ID tt18076678.Vamos por la iteración: 37.
# Hemos añadido la peli Los Wánabis a la lista sin tomatometer. Vamos por la iteración: 38.
# Hemos añadido la peli Empieza el baile a la lista sin tomatometer. Vamos por la iteración: 39.
# La tupla de la peli Back to the Present! no está completa: (None, 'Justin Souriau-Levine', 'Justin Souriau-Levine', 'A government issued science experiment sends five theater actors on a journey through time and space via a virtual reality vortex. They are sent back to the Wild West (19th century), Prehistoric times (50,000 BC), Medieval Times (12th century), The Golden Age of Piracy (17th century), WW2 Prisoner of War Camps (1940s); and sent forward in time to a colorful Parallel F... Leer todo', 'Acción\nAventura\nComedia', None, 'Back to the Present!') Vamos por la iteración: 40
# Hemos añadido la peli Murdercise a la lista sin tomatometer. Vamos por la iteración: 41.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 42
# No se encontró el elemento de búsqueda para la película Mari(dos) con ID tt18393816.Vamos por la iteración: 43.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 44
# No se encontró el elemento de búsqueda para la película Dead English con ID tt18567620.Vamos por la iteración: 45.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 46
# No se encontró el elemento de búsqueda para la película Vanitose (Vanity) con ID tt18690646.Vamos por la iteración: 47.
# La tupla de la peli Astray no está completa: (None, None, None, 'Three kids get separated in a forest after one of them disappears from the trail.', 'Corto', '21min', 'Astray') Vamos por la iteración: 48
# Hemos añadido la peli Bad Boy a la lista completa. Vamos por la iteración: 49.
# La tupla de la peli The Place in Between no está completa: (None, 'Laura Perez', 'Valerie MichelsonLaura Perez', "Stoic and uptight L.A. lawyer, Cassie, is forced to return to Texas and meet her estranged and angsty teen daughter, Lyra when Lyra's father dies unexpectedly. Their personalities collide the moment they meet, especially since Cassie has not seen her daughter since birth. Their union is further strained when they are tasked to fulfill Lyra's father's last wish to have... Leer todo", 'Drama', None, 'The Place in Between') Vamos por la iteración: 50
# Hemos añadido la peli Los juegos del hambre: Balada de pájaros cantores y serpientes a la lista completa. Vamos por la iteración: 51.
# La tupla de la peli Raw Power no está completa: (None, '83%', 'Michael R. Farinelli', 'Troy EscodaDiezel RamosKelly Alejandra Cantoral', 'Five time world power lifting champion Diezel "Da Destroyer" Rodriguez is harassed out of retirement by an upcoming, vicious, ruthless underdog known as Skylor "The Crucifier" Jackson to obtain the recognition of world\'s greatest power lifter. Disputed by Diezel\'s manager, trainer, doctor, ex-wife and daughter regarding Diezel\'s serious health issues, Diezel still dec... Leer todo', 'Drama', None, 'Raw Power') Vamos por la iteración: 52
# Hemos añadido la peli El peor equipo del mundo (Next Goal Wins) a la lista sin tomatometer. Vamos por la iteración: 53.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 54
# No se encontró el elemento de búsqueda para la película Minamoto Monogatari con ID tt10929648.Vamos por la iteración: 55.
# La tupla de la peli Mujeres Silenciosas no está completa: (None, None, None, None, None, None, 'Mujeres Silenciosas') Vamos por la iteración: 56
# Hemos añadido la peli Silent Life: The Story of the Lady in Black a la lista sin tomatometer. Vamos por la iteración: 57.
# La tupla de la peli The Silent Prayer no está completa: (None, '16%', 'Nick Westerlund', 'Nick Westerlund', "In a small, quiet town, a young boy named Samuel witnesses a horrific event that changes his life forever. One fateful night, Samuel's mother is tragically killed. The incident leaves Samuel heartbroken and traumatized, having to face the harsh reality of life without his mother. As he grapples with his emotions, he struggles with anger, sadness, and confusion. He fee... Leer todo", 'Drama', None, 'The Silent Prayer') Vamos por la iteración: 58
# Hemos añadido la peli Amadeo a la lista sin tomatometer. Vamos por la iteración: 59.
# Hemos añadido la peli Creed III a la lista sin tomatometer. Vamos por la iteración: 60.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 61
# No se encontró el elemento de búsqueda para la película Dark Room con ID tt11196176.Vamos por la iteración: 62.
# La tupla de la peli Ai Lun no está completa: (None, 'Hector Abaunza', 'Hector Abaunza', '', 'Drama', '1h 35min', 'Ai Lun') Vamos por la iteración: 63
# La tupla de la peli Divine Flames no está completa: (None, 'Natasha Thompson', 'Kyle Helsper', 'this is a romantic drama of a witch on her twin flame journey', 'Drama', '1h 30min', 'Divine Flames') Vamos por la iteración: 64
# La tupla de la peli Divine Flames no está completa: (None, 'Natasha Thompson', 'Natasha ThompsonKyle Helsper', 'this is a romantic drama of a witch on her twin flame journey', 'Drama', '1h 30min', 'Divine Flames') Vamos por la iteración: 65
# La tupla de la peli Vincent no está completa: (None, '78%', 'David Noel Bourke', 'David Noel Bourke', "Nobody can understand you when you're 14. Except possibly a monster. A bullied teenager meets a stranger from out of town and they form an unusual relationship.", 'Drama', '1h 24min', 'Vincent') Vamos por la iteración: 66
# La tupla de la peli Black Nightmares no está completa: (None, '34%', 'Sanjay Mengar', 'Sanjay Mengar', 'A beautiful house is ready for a migrated family who have no idea about the hidden tales inside the house. The family man starts having nightmares which are based on the things happened on the same day. Instead of running away, the man chases the nightmares to find out the truth of any connection between the house and nightmares.', 'Drama', '1h 20min', 'Black Nightmares') Vamos por la iteración: 67
# La tupla de la peli Yuna no está completa: (None, 'Hector Abaunza', 'Hector Abaunza', '', 'Drama', None, 'Yuna') Vamos por la iteración: 68
# Hemos añadido la peli Pátria a la lista sin tomatometer. Vamos por la iteración: 69.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 70
# No se encontró el elemento de búsqueda para la película Extraordinary Sacrifice con ID tt11601444.Vamos por la iteración: 71.
# La tupla de la peli Oliver Outloud no está completa: (None, None, None, None, None, None, 'Oliver Outloud') Vamos por la iteración: 72
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 73
# No se encontró el elemento de búsqueda para la película Ladies Are Pimps Too con ID tt11779282.Vamos por la iteración: 74.
# Hemos añadido la peli Sophie's Rules a la lista sin tomatometer. Vamos por la iteración: 75.
# La tupla de la peli Bugsy the Becoming no está completa: (None, 'George Easley', 'Prince GeorgeGeorge Lawson-Easley', 'When a vile creature sets out to destroy the calm, and the world as we know it, and to keep the world from going into complete chaos, one city at a time, has to prove he is the one who can stop this vile creature, and right the wrongs,', 'Acción', '2h', 'Bugsy the Becoming') Vamos por la iteración: 76
# Hemos añadido la peli Varisu a la lista sin tomatometer. Vamos por la iteración: 77.
# Hemos añadido la peli El color púrpura a la lista completa. Vamos por la iteración: 78.
# La tupla de la peli Karanliktaki Kadin no está completa: (None, 'Aksel Yakup Bektas', 'Aksel Yakup Bektas', 'The scary story of a woman who died nearly 100 years ago.', 'Drama', None, 'Karanliktaki Kadin') Vamos por la iteración: 79
# La tupla de la peli Romeo Is Dead no está completa: (None, 'Dominic Giannetti', 'Dominic Giannetti', '', 'Drama', None, 'Romeo Is Dead') Vamos por la iteración: 80
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 81
# No se encontró el elemento de búsqueda para la película Big George Foreman con ID tt12226632.Vamos por la iteración: 82.
# Hemos añadido la peli 65 a la lista sin tomatometer. Vamos por la iteración: 83.
# La tupla de la peli Getting to the Plug no está completa: (None, 'Jeff Profitt', 'Jeff Profitt', 'Detective Henderson is a no nonsense undercover female Police Detective, with a stellar record of always taking down the target of her investigations. Henderson gets requested by her superiors to go undercover and take down a local drug dealer. The dealer, Darius Miller, has recently become the biggest supplier of illegal narcotics in the region. Known as "The Plug", ... Leer todo', 'Acción\nCrimen\nDrama', '1h 15min', 'Getting to the Plug') Vamos por la iteración: 84
# Hemos añadido la peli Central Valley a la lista sin tomatometer. Vamos por la iteración: 85.
# Hemos añadido la peli Embaucadores a la lista sin tomatometer. Vamos por la iteración: 86.
# Hemos añadido la peli The Nothingness Club - Não Sou Nada a la lista sin tomatometer. Vamos por la iteración: 87.
# La tupla de la peli The Internationalist no está completa: (None, 'Yolanda Torres', 'Yolanda Torres', 'A disillusioned Australian photographer who once dreamed of glory as a documentarian of the human condition discovers his real grandfather was a heroic war correspondent who disappeared during the Spanish Civil War and, alongside a rebel journalist, goes on a quest to find him (and himself) before his nurse turned resistance fighter grandmother passes away to ultimate... Leer todo', 'Drama', '1h 54min', 'The Internationalist') Vamos por la iteración: 88
# Hemos añadido la peli Adipurush a la lista sin tomatometer. Vamos por la iteración: 89.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 90
# No se encontró el elemento de búsqueda para la película Gouge con ID tt12942176.Vamos por la iteración: 91.
# La tupla de la peli Rhythm in Blues no está completa: (None, None, None, None, None, '1h 50min', 'Rhythm in Blues') Vamos por la iteración: 92
# Hemos añadido la peli Shehzada a la lista sin tomatometer. Vamos por la iteración: 93.
# Hemos añadido la peli Mission Majnu a la lista sin tomatometer. Vamos por la iteración: 94.
# Hemos añadido la peli Bholaa Shankar a la lista sin tomatometer. Vamos por la iteración: 95.
# Hemos añadido la peli Demir Kadin Neslican a la lista sin tomatometer. Vamos por la iteración: 96.
# La tupla de la peli Meeting Kate no está completa: (None, 'Jefferson Moore', 'Jefferson Moore', 'This prequel to Reading Kate (2015) tells the story of Michael and Kate, their chance romance, and their challenges of building a life together despite their overwhelming differences.', 'Drama', None, 'Meeting Kate') Vamos por la iteración: 97
# Hemos añadido la peli Reptiles a la lista sin tomatometer. Vamos por la iteración: 98.
# Hemos añadido la peli Los buenos modales a la lista sin tomatometer. Vamos por la iteración: 99.
# La tupla de la peli Broken Pearls no está completa: (None, 'Fredy Polania', 'Fredy Polania', 'A Mexican Journalist (Veronica Sanchez) quits her job and embarks on a journey to find the lost voices left from the Russian Invasion.', 'Drama', None, 'Broken Pearls') Vamos por la iteración: 100
# La tupla de la peli Oneida Flats no está completa: (None, 'Danny Winn', 'Maria Elena HarrisonM.H. Ploof', 'In 1921, in a small town in upper state New York, one family\'s story of murder, kidnapping and survival is stranger than fiction, because it\'s true. "Family is love, murder is business."', 'Drama', None, 'Oneida Flats') Vamos por la iteración: 101
# Hemos añadido la peli Sombras Blancas a la lista sin tomatometer. Vamos por la iteración: 102.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 103
# No se encontró el elemento de búsqueda para la película Tarifte Ask Var con ID tt13683908.Vamos por la iteración: 104.
# Hemos añadido la peli Animal a la lista sin tomatometer. Vamos por la iteración: 105.
# Hemos añadido la peli Shaakuntalam a la lista sin tomatometer. Vamos por la iteración: 106.
# La tupla de la peli The Assassin Unleashed no está completa: (None, 'JJ Stomp', 'Aki AleongJJ Stomp', '', 'Acción', None, 'The Assassin Unleashed') Vamos por la iteración: 107
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 108
# No se encontró el elemento de búsqueda para la película Spider-Man: Lotus con ID tt13904644.Vamos por la iteración: 109.
# Hemos añadido la peli Vuelo al límite a la lista sin tomatometer. Vamos por la iteración: 110.
# Hemos añadido la peli Rustin a la lista completa. Vamos por la iteración: 111.
# Hemos añadido la peli Bullets a la lista completa. Vamos por la iteración: 112.
# Hemos añadido la peli Bratri a la lista sin tomatometer. Vamos por la iteración: 113.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 114
# No se encontró el elemento de búsqueda para la película Mrs. Chatterjee vs. Norway con ID tt14295590.Vamos por la iteración: 115.
# Hemos añadido la peli Peripheric Love a la lista sin tomatometer. Vamos por la iteración: 116.
# La tupla de la peli The Judas Kiss no está completa: (None, 'Alexander Emmert', 'Alexander Emmert', 'A writer, an actor and the actor\'s wife are immersed in a love triangle, set against the backdrop of McCarthy era "blacklisting"; the actor\'s testimony sends the writer to prison, during which time he writes a play about betrayal, producing it upon his release with the actor starring in the lead role.', 'Drama', '1h 31min', 'The Judas Kiss') Vamos por la iteración: 117
# Hemos añadido la peli My Precious a la lista sin tomatometer. Vamos por la iteración: 118.
# La tupla de la peli In Control of Me no está completa: (None, 'Christopher Siaens', 'Christopher Siaens', 'A domestic violence awareness story. An abused girl fights within herself to break free of a controlled, manipulative relationship.', 'Corto', '2min', 'In Control of Me') Vamos por la iteración: 119
# La tupla de la peli Tomorrow Before After no está completa: ('6,5', '45%', 'Alfonso Quijada', 'Alfonso Quijada', 'En un mundo postapocalíptico, una joven, con la ayuda de un perro abandonado, busca a otros supervivientes mientras intenta lidiar con un niño nonato que crece en su interior.', 'Drama', None, 'Tomorrow Before After') Vamos por la iteración: 120
# Hemos añadido la peli Shin Kamen Raidâ a la lista completa. Vamos por la iteración: 121.
# Hemos añadido la peli Tiroteo en Rio Bravo a la lista sin tomatometer. Vamos por la iteración: 122.
# La tupla de la peli Bury a Dream no está completa: (None, 'Carol Del Mar', 'Carol Del Mar', "A grieving teen's sleepwalking disorder spirals into a nightmare.", 'Corto', None, 'Bury a Dream') Vamos por la iteración: 123
# La tupla de la peli 1919 no está completa: (None, None, None, None, None, None, '1919') Vamos por la iteración: 124
# Hemos añadido la peli Paint a la lista completa. Vamos por la iteración: 125.
# La tupla de la peli Halfway House no está completa: (None, 'Marc Cayce', 'Marc Cayce', 'Seven troubled adult men struggle to live together in a private halfway house located in a wealthy section of Los Angeles, CA. The large house is owned by a divorced couple, Dr. MARC CASEY, a Doctor of Psychology and therapist and YOLANDA CASEY who is a candidate for the U.S. Senate. The only thing they agree on is sharing the income generated from the house that is p... Leer todo', 'Crimen', '1h 40min', 'Halfway House') Vamos por la iteración: 126
# Hemos añadido la peli Les âmes soeurs a la lista sin tomatometer. Vamos por la iteración: 127.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 128
# No se encontró el elemento de búsqueda para la película SoulHood Saga II: The Finale con ID tt14681272.Vamos por la iteración: 129.
# La tupla de la peli Pieces of My Husband & His Friends no está completa: (None, None, None, None, None, None, 'Pieces of My Husband & His Friends') Vamos por la iteración: 130
# La tupla de la peli The Psychology of Beauty no está completa: (None, 'Savanna Crasto', 'Savanna Crasto', 'As part of a cabaret show, five cast members and their director play with the idea of normalising the destruction of a construct that determines what we eat, how we breathe and the words we speak.', 'Drama', None, 'The Psychology of Beauty') Vamos por la iteración: 131
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 132
# No se encontró el elemento de búsqueda para la película A Princesa de Rangoon con ID tt14797058.Vamos por la iteración: 133.
# La tupla de la peli Big Sur no está completa: (None, 'Tim Foley', 'Halle ArbaughHalle Sparrow', 'Music video short shot in Big Sur, California.', 'Documental', '5min', 'Big Sur') Vamos por la iteración: 134
# La tupla de la peli 90's Babiez no está completa: (None, None, None, None, None, '2h 52min', "90's Babiez") Vamos por la iteración: 135
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 136
# No se encontró el elemento de búsqueda para la película Satyaprem Ki Katha con ID tt14914988.Vamos por la iteración: 137.
# La tupla de la peli Wayward Sons no está completa: (None, 'Cole McCormack', 'Joseph Loeffler-BellCole McCormackNick Richards', 'Brothers Robert (Joseph Loeffler-Bell) and Todd (Nick Richards) hike through the Chequamegon-Nicolet National Forest, but they stray so far from the trail that they have no idea how to get back. Initially, they maintain morale by rehashing old stories and reciting inside jokes, but the gravity of their situation sinks in as a return to civilization becomes more unlike... Leer todo', 'Drama', '1h', 'Wayward Sons') Vamos por la iteración: 138
# La tupla de la peli A Small Town Christmas no está completa: (None, 'David Wendell Boykins', 'Gin Blanton', "Summer O'Neal is an attorney that handles accident cases. She hasn't seen her family for Christmas in years. However, this Christmas, her grandmother is ill . Summer will face her fears and go home to her small town for Christmas.", 'Drama', None, 'A Small Town Christmas') Vamos por la iteración: 139
# La tupla de la peli First Nights no está completa: (None, 'Jack Prabhu', 'Jack Prabhu', 'A 4-chapter anthology of 7 couples in one broad backdrop - the first night of marriage.', 'Comedia\nDrama\nRomance', '1h 46min', 'First Nights') Vamos por la iteración: 140
# Hemos añadido la peli Rocky Aur Rani Kii Prem Kahaani a la lista sin tomatometer. Vamos por la iteración: 141.
# La tupla de la peli FOG no está completa: (None, 'Alex Anderson', 'Alex Anderson', 'A comedy writer experiencing a fallow period goes home for the weekend in the hopes that the complicated relationship she has with her mother will be the spark to her creativity needed to finish a script that is due.', 'Drama', None, 'FOG') Vamos por la iteración: 142
# Hemos añadido la peli Exodus a la lista completa. Vamos por la iteración: 143.
# Hemos añadido la peli Hajjan a la lista sin tomatometer. Vamos por la iteración: 144.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 145
# No se encontró el elemento de búsqueda para la película Winnie Pooh Blood and Thunder con ID tt15070886.Vamos por la iteración: 146.
# Hemos añadido la peli Mon chat et moi, la grande aventure de Rroû a la lista sin tomatometer. Vamos por la iteración: 147.
# La tupla de la peli Love Is Not Enduring no está completa: (None, 'Cecilia Okugo', 'Cecilia Okugo', "Clarissa and Tommy blend their companies and fall in love. After the announcement of those engagement Clarissa's old college friends set out for revenge assuring Clarissa never marries. Do Tommy and Clarissa make it down the aisle?", 'Drama', None, 'Love Is Not Enduring') Vamos por la iteración: 148
# La tupla de la peli My World no está completa: (None, '72%', 'Samuel Rees', 'Samuel Rees', 'Sophie struggles with her mental health as she navigates the dangerous waters of relationships, parties, drugs and managing her relationship with her dysfunctional family.', 'Drama', None, 'My World') Vamos por la iteración: 149
# La tupla de la peli The Inn Between no está completa: (None, None, None, None, None, None, 'The Inn Between') Vamos por la iteración: 150
# La tupla de la peli Divine Souls: Forever Young no está completa: (None, None, None, None, None, None, 'Divine Souls: Forever Young') Vamos por la iteración: 151
# La tupla de la peli Jade Brooks Must Die! no está completa: (None, '82%', 'Jane Chua', 'Jane Chua', "Sometimes, destiny is very cruel to every creature. There is a success, and there is a failure. Despite the sweet laughter, there are hidden complex pasts that are difficult to accept but must be upheld, fought for conquered for the sake of others. What is the awaiting fate of the Onna-Bugeisha who's desire is to conquer the gigantic giants who give horror to society ... Leer todo", 'Acción', '1h 55min', 'Jade Brooks Must Die!') Vamos por la iteración: 152
# La tupla de la peli Hela bilden no está completa: (None, 'Nouva Monika Wahlgren', 'Nouva Monika Wahlgren', 'Albert is unwilling to change his old ways of living, in a dystopian future society, therefore he encounters problems on his journey', 'Comedia', '2h', 'Hela bilden') Vamos por la iteración: 153
# Hemos añadido la peli Andra akten a la lista sin tomatometer. Vamos por la iteración: 154.
# Hemos añadido la peli En dag kommer allt det här bli ditt a la lista sin tomatometer. Vamos por la iteración: 155.
# Hemos añadido la peli Rudhran a la lista sin tomatometer. Vamos por la iteración: 156.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 157
# No se encontró el elemento de búsqueda para la película Kos con ID tt15341416.Vamos por la iteración: 158.
# La tupla de la peli Ill Intent no está completa: (None, 'Taj Mitchell', 'Taj Mitchell', "Terrance and Tracey Davis are getting ready to have their first child. They both want to have a in home birth with a Doula. Tracey doesn't know her trust will be betrayed and she will be living a nightmare.", 'Drama', None, 'Ill Intent') Vamos por la iteración: 159
# Hemos añadido la peli Let the Party Begin a la lista sin tomatometer. Vamos por la iteración: 160.
# Hemos añadido la peli Oppenheimer a la lista sin tomatometer. Vamos por la iteración: 161.
# La tupla de la peli Jasmine no está completa: (None, '60%', 'Swan Sindhu Moti', 'Ryan PhillipsMargaret Frances', '', 'Drama', '1h 21min', 'Jasmine') Vamos por la iteración: 162
# Hemos añadido la peli Nigah Marda Ayi Ve a la lista sin tomatometer. Vamos por la iteración: 163.
# Hemos añadido la peli Long ma jing shen a la lista sin tomatometer. Vamos por la iteración: 164.
# La tupla de la peli Bravado no está completa: (None, 'Tom Beaver', 'Tom Beaver', 'A comedy-drama about a middle-aged creative writing instructor struggling with the recent suicide of one of his students, a divorce, a strangely unfolding Eco-anxiety (Solastalgia) and his evolving relationship to the shifting attitudes of society.', 'Drama', '32min', 'Bravado') Vamos por la iteración: 165
# La tupla de la peli 2030 no está completa: (None, 'Tim Eickhoff', 'Tim EickhoffTimo Martens', '2030. In a new world. Pregnancies are forbidden. Emily must make a life changing decision.', 'Corto', '21min', '2030') Vamos por la iteración: 166
# Hemos añadido la peli Oluja a la lista sin tomatometer. Vamos por la iteración: 167.
# Hemos añadido la peli Ovuda ce proci put a la lista sin tomatometer. Vamos por la iteración: 168.
# Hemos añadido la peli Le grand chariot a la lista sin tomatometer. Vamos por la iteración: 169.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 170
# No se encontró el elemento de búsqueda para la película Vicino al Verbo con ID tt15595576.Vamos por la iteración: 171.
# La tupla de la peli The Obstacle no está completa: (None, None, None, None, 'Drama', None, 'The Obstacle') Vamos por la iteración: 172
# Hemos añadido la peli Return of the Dark a la lista completa. Vamos por la iteración: 173.
# La tupla de la peli Vaarta Re Vaarta no está completa: (None, 'Amit Ramesh Rughani', 'Amit Ramesh Rughani', '', 'Crimen', None, 'Vaarta Re Vaarta') Vamos por la iteración: 174
# La tupla de la peli Merrily no está completa: (None, 'Robert McAtee', 'Robert McAtee', '', 'Drama', None, 'Merrily') Vamos por la iteración: 175
# La tupla de la peli My Week no está completa: (None, 'Gin Blanton', 'Gin Blanton', "Jade Gooding is a career driven over-achiever on the fast track of success. She is just as aggressive and power hungry for a VP title as her male counterparts. But this over thirty and single Marketing Director longs for love and affection from a man her equal. Having endured a number of meaningless dates and advances from co-workers that just don't measure up, Jade's... Leer todo", 'Drama', None, 'My Week') Vamos por la iteración: 176
# Hemos añadido la peli 129 a la lista sin tomatometer. Vamos por la iteración: 177.
# La tupla de la peli Plymouth no está completa: (None, 'Mark Penney', 'Mark Penney', 'Plot is undisclosed at this time.', 'Drama', None, 'Plymouth') Vamos por la iteración: 178
# La tupla de la peli Out for Vengeance no está completa: (None, 'Salar Zarza', 'Salar Zarza', 'Stuck between European drug cartels Alan Barnas, an ex-veteran, decides to take matters into his own hands when the police fail to solve a murder.', 'Acción\nCrimen\nDrama', None, 'Out for Vengeance') Vamos por la iteración: 179
# La tupla de la peli Penance no está completa: (None, 'Dante Moran', 'Dante Moran', 'A methodical serial killer known as The Inferno Killer terrorizes the beautiful city of San Diego by murdering his victims according to the punishments within the 9 Circles of Hell.', 'Crimen\nDrama\nTerror', '1h 30min', 'Penance') Vamos por la iteración: 180
# Hemos añadido la peli La Pura Vida a la lista sin tomatometer. Vamos por la iteración: 181.
# La tupla de la peli A Little Resistance no está completa: (None, 'Michael Loder', 'Michael LoderCharles Jazz Terrier', "In an industrial fantasy world, tensions ignite a war between two nations. Princess Sophia joins resistance fighters, defying her father's rule in the struggle for freedom.", 'Drama', '1h 46min', 'A Little Resistance') Vamos por la iteración: 182
# Hemos añadido la peli Mascotte a la lista sin tomatometer. Vamos por la iteración: 183.
# La tupla de la peli Wormwood: A German Expressionistic Dystopia no está completa: (None, 'Kevin Lucero Less', 'Kevin Lucero Less', 'A language driven dark comedy about a young man who is plucked from obscurity by the motion picture industry, and the trials and tribulations therein.', 'Comedia', '1h 30min', 'Wormwood: A German Expressionistic Dystopia') Vamos por la iteración: 184
# La tupla de la peli Xmas no está completa: (None, 'Christopher Baiza', 'Christopher Baiza', 'In the shadows of uncertainty, between logic and wonder, shadow and light, Harold Johnson finds himself in the twilight zone.', 'Corto', None, 'Xmas') Vamos por la iteración: 185
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 186
# No se encontró el elemento de búsqueda para la película Jeff the Policeman Movie con ID tt7713452.Vamos por la iteración: 187.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 188
# No se encontró el elemento de búsqueda para la película The Strays con ID tt16437278.Vamos por la iteración: 189.
# Hemos añadido la peli Statica a la lista sin tomatometer. Vamos por la iteración: 190.
# Hemos añadido la peli Brooklyn 45 a la lista sin tomatometer. Vamos por la iteración: 191.
# Hemos añadido la peli El imaginario a la lista sin tomatometer. Vamos por la iteración: 192.
# Hemos añadido la peli Camino de la venganza a la lista sin tomatometer. Vamos por la iteración: 193.
# La tupla de la peli Multiverso no está completa: (None, 'Juanjo Martínez', 'Juanjo Martínez', 'A drama, which explores unknown earths of the DC Universe.', 'Acción', None, 'Multiverso') Vamos por la iteración: 194
# La tupla de la peli Detour 95 no está completa: (None, 'James Twyman', 'Matthew Clark "Ghost"Tesha Clark', 'Candace se marcha del norte de Nueva Jersey a Miami, Florida, para escapar de la violencia y la pobreza; pronto se encuentra luchando por su vida en una pesadilla de paletos.', 'Acción', None, 'Detour 95') Vamos por la iteración: 195
# La tupla de la peli The Legend of Johnny Jones no está completa: (None, 'James Twyman', 'Matthew Clark "Ghost"Tesha Clark', 'Ambientada en los proyectos de vivienda de Nueva Jersey. Un joven que solo ha conocido la pobreza y el abuso toda su vida, sufre un colapso mental y se embarca en una ola de asesinatos como ninguna otra en la historia.', 'Acción', None, 'The Legend of Johnny Jones') Vamos por la iteración: 196
# La tupla de la peli Slasher House 3 no está completa: ('6,4', 'Mj Dixon', 'Mj Dixon', "It's out of the frying pan and into the fire for our heroes as they discover the truth behind Project Slasher House and H.E.X.A.G.O.N. where Red makes her last stand against an army of Government ops and NEW deadlier killers, the truth will finally be revealed.", 'Acción', None, 'Slasher House 3') Vamos por la iteración: 197
# La tupla de la peli Clank and the Golden Scar no está completa: (None, 'Pauli Janhunen Calderón', 'Pauli Janhunen Calderón', 'Two missions taking place simultaneously in different decades where both C.I.S. Agents going under the alias Clank went up against the dangerous crime lord known as Goldscar.', 'Acción', None, 'Clank and the Golden Scar') Vamos por la iteración: 198
# Hemos añadido la peli Furiosa: De la saga Mad Max a la lista sin tomatometer. Vamos por la iteración: 199.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 200
# No se encontró el elemento de búsqueda para la película Eddie Thurber-IV-Victor the Shovel Returns con ID tt12925840.Vamos por la iteración: 201.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 202
# No se encontró el elemento de búsqueda para la película Mnemonix con ID tt13590374.Vamos por la iteración: 203.
# Hemos añadido la peli Fighter a la lista sin tomatometer. Vamos por la iteración: 204.
# La tupla de la peli L'Inferno (Remastered) no está completa: (None, 'Francesco Bertolini', 'Dante AlighieriDino Di Durante', "L'Inferno (1911) was the first Italian feature production in history. It was originally filmed in black and white and as a silent film.", 'Acción', '1h 3min', "L'Inferno (Remastered)") Vamos por la iteración: 205
# Hemos añadido la peli Guntur Kaaram a la lista sin tomatometer. Vamos por la iteración: 206.
# La tupla de la peli Superman: Jubilation no está completa: (None, '29%', 'Ricardo Rodriguez', 'Ricardo Rodriguez', 'This story focuses on the version of Superman that many forget, the story of Val-El the Earth 2 Superman. The film follows Val-El on his journey to find his purpose among a race that views him as an outsider.', 'Acción', '1h', 'Superman: Jubilation') Vamos por la iteración: 207
# La tupla de la peli Jessica Frost no está completa: (None, 'Ru Berntsen', 'Cristo M. Sanchez', 'Una joven que busca la verdad sobre por qué la persigue un psicópata que viaja en el tiempo, se ve inmersa en un turbulento viaje a través del desierto, el tiempo, el espacio y el pasado de su familia.', 'Acción', '16+', 'Jessica Frost') Vamos por la iteración: 208
# La tupla de la peli Kraven el cazador no está completa: (None, 'J.C. Chandor', 'Richard Wenk', 'El inmigrante ruso Sergei Kravinoff está en una misión para demostrar que es el mejor cazador del mundo.', 'Acción\nAventura\nCiencia ficción', None, 'Kraven el cazador') Vamos por la iteración: 209
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 210
# No se encontró el elemento de búsqueda para la película Trail Blazers: The Aftermath (Part 1) con ID tt15716012.Vamos por la iteración: 211.
# Hemos añadido la peli Yodha a la lista sin tomatometer. Vamos por la iteración: 212.
# La tupla de la peli Sheran Di Kaum Punjabi no está completa: (None, 'Gippy Grewal', 'Gippy GrewalNasir', '', 'Acción', None, 'Sheran Di Kaum Punjabi') Vamos por la iteración: 213
# La tupla de la peli Dying for Living no está completa: (None, 'Patrick Kilpatrick', 'Patrick KilpatrickHeidi BrightMariya Samoylova', "'Dying for Living' takes you on a thrilling journey into the chaotic world of an aging hitman, consumed by vanity. In a daring quest for redemption, he sets out to gather his long-abandoned family of skilled assassins in the heart of Holland and Hollywood. Their reunion will unleash a storm of mayhem and intrigue. As the twisted plot unfolds, dark secrets surface, all... Leer todo", 'Acción', '1h 30min', 'Dying for Living') Vamos por la iteración: 214
# La tupla de la peli Dead Heist no está completa: (None, None, None, None, None, None, 'Dead Heist') Vamos por la iteración: 215
# Hemos añadido la peli Bade Miyan Chote Miyan a la lista sin tomatometer. Vamos por la iteración: 216.
# La tupla de la peli Chromakill no está completa: (None, None, None, None, None, '35min', 'Chromakill') Vamos por la iteración: 217
# La tupla de la peli SI-BO no está completa: (None, 'Jannik Schwerdt', 'Jannik Schwerdt', 'An action-packed Star Wars fan film, which tells the story of the young Padawan "SI-BO". He and his master "Quinn" plunge into the unknown and are put to the test.', 'Corto\nAcción\nCiencia ficción', None, 'SI-BO') Vamos por la iteración: 218
# La tupla de la peli The Last Aztec Warrior no está completa: (None, 'Anthony Islas', 'Anthony Islas', 'It tells the story of a man who is extracted from federal prison and called to do one last job to take down a notorious druglord.', 'Acción', None, 'The Last Aztec Warrior') Vamos por la iteración: 219
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 220
# No se encontró el elemento de búsqueda para la película Karate Kid con ID tt22084516.Vamos por la iteración: 221.
# La tupla de la peli Loaded Deliberation no está completa: (None, 'Cayde Joy', 'Cayde Joy', 'A group of bank robbers hide out in an abandoned warehouse after a job. Will greed get the best of them? Who will make it out alive?', 'Corto', None, 'Loaded Deliberation') Vamos por la iteración: 222
# La tupla de la peli The Dark Face no está completa: (None, 'Senthilkumar Alamuthu', 'Senthilkumar Alamuthu', '', 'Acción', None, 'The Dark Face') Vamos por la iteración: 223
# Hemos añadido la peli Dark Fusion a la lista sin tomatometer. Vamos por la iteración: 224.
# Hemos añadido la peli The Experts a la lista sin tomatometer. Vamos por la iteración: 225.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 226
# No se encontró el elemento de búsqueda para la película Pedro Marquez Y la Ines Una Pareja Implacable Los de la Camioneta Gris con ID tt27451262.Vamos por la iteración: 227.
# La tupla de la peli Mandya no está completa: (None, 'Sanjay Niranjan', 'Sanjay Niranjan', 'Four Boys come to Mandya from Different place of India to start their career in crime and extortion from builders and high profiles peoples and they succeed...One day things take a turn when one of them (ganpat) missing.', 'Acción', None, 'Mandya') Vamos por la iteración: 228
# La tupla de la peli Terminator: Skynet Rising no está completa: (None, 'Rui Constantino', 'Rui Constantino', 'Desde que Legión fue destruida, las máquinas han estado trabajando para restaurar Skynet. Ahora la resistencia ha descubierto sus planes y debe encontrar la forma de impedirlo.', 'Acción\nTerror\nCiencia ficción', None, 'Terminator: Skynet Rising') Vamos por la iteración: 229
# La tupla de la peli Pimpin Aint Dead Movie no está completa: (None, 'Flukie Stoaks', 'Flukie Stoaks', '', 'Acción', 'Not Rated', 'Pimpin Aint Dead Movie') Vamos por la iteración: 230
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 231
# No se encontró el elemento de búsqueda para la película Kamen Rider 555 20th: Paradise Regained con ID tt27679654.Vamos por la iteración: 232.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 233
# No se encontró el elemento de búsqueda para la película Insurgency con ID tt27819748.Vamos por la iteración: 234.
# La tupla de la peli Insurgency: Part One no está completa: (None, 'Daniel McQuade', 'Daniel McQuade', "The chilling conclusion to The Network has arrived. When a dangerous military emerges from the shadows, all of the personalities within The Network must unite one last time to prevent the catastrophic destruction of Harry's mind.", 'Corto', '41min', 'Insurgency: Part One') Vamos por la iteración: 235
# La tupla de la peli Insurgency: Part Two no está completa: (None, '92%', 'Daniel McQuade', 'Daniel McQuade', "In the final part of the epic conclusion to The Network, Jay takes the fight to Ethan in a desperate attempt to save Harry. There is no room for failure as Jay balances not only his life, but Harry's life in the palm of his hand.", 'Corto', '38min', 'Insurgency: Part Two') Vamos por la iteración: 236
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 237
# No se encontró el elemento de búsqueda para la película Eagle con ID tt28074691.Vamos por la iteración: 238.
# La tupla de la peli Take Cover no está completa: (None, 'Nick McKinless', 'Joshua Todd James', 'Un francotirador profesional quemado se encuentra atrapado en un ático de cristal por un competidor letal y debe encontrar una manera de sobrevivir y escapar con poca o ninguna cobertura entre él y el asesino.', 'Acción', None, 'Take Cover') Vamos por la iteración: 239
# La tupla de la peli Final Jeopardy no está completa: (None, None, None, None, 'Acción', None, 'Final Jeopardy') Vamos por la iteración: 240
# La tupla de la peli Bélico no está completa: (None, 'Heruz Argenis', None, 'A capo hires a young man, AKA "El Diez," to learn about his affairs. When a group of rebels complots to betray him, "El Diez" will prove his loyalty to his boss, who knows more than his treacherous workers would have imagined.', 'Acción', '1h 35min', 'Bélico') Vamos por la iteración: 241
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 242
# No se encontró el elemento de búsqueda para la película Rode College con ID tt28350704.Vamos por la iteración: 243.
# La tupla de la peli Michelle - the fall Trinidad and Tobago film no está completa: (None, 'Keyon Byron', 'Keyon Byron', "Consumed by her past, Michelle seeks to avenge her parent's death while dealing with her new found powers. The short films stars Angelia Bissoon as Michelle Hernandez, Maurice George as Conner Lockwood,Sameerah Osborne-Pope as Adira,Joel Anthony Woo Chong as Alvaro Hernandez,Saraswati Ramlogan as Icy,Sydney Ledger as Paralysis,Keyon Byron as Batchack-Man,Luis Freites ... Leer todo", 'Corto', None, 'Michelle - the fall Trinidad and Tobago film') Vamos por la iteración: 244
# La tupla de la peli Hyena no está completa: (None, '57%', None, None, None, None, None, 'Hyena') Vamos por la iteración: 245
# Hemos añadido la peli Sheriff: Narko Integriti a la lista sin tomatometer. Vamos por la iteración: 246.
# La tupla de la peli Sith Wars: Episódio III - Fantasmas Dos Sith no está completa: (None, '79%', 'Rui Constantino', 'Rui Constantino', "Darth Vader finally arrived at Korriban to unlock it's secrets to himself. And he has Jakkai locked away in his super star destroyer, tempting him to turn to the darkside of the force.. Gordon along with Grogu, try to save him.", 'Acción\nFantasía\nCiencia ficción', None, 'Sith Wars: Episódio III - Fantasmas Dos Sith') Vamos por la iteración: 247
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 248
# No se encontró el elemento de búsqueda para la película The Take con ID tt28756051.Vamos por la iteración: 249.
# La tupla de la peli The Emancipation of Jack Lopez no está completa: (None, 'Kane Vallance', 'Fynn Wigginton', 'In this sequel short film, we find Jack Lopez living alone following the events of Estramia (2024) struggling to find work and survive without his family in a slowly rebuilding land.', 'Corto', '8min', 'The Emancipation of Jack Lopez') Vamos por la iteración: 250
# La tupla de la peli Paruthlaak no está completa: (None, 'Arjun', None, '', 'Corto', None, 'Paruthlaak') Vamos por la iteración: 251
# La tupla de la peli Super Vixens 6 no está completa: (None, 'Mister Hero', 'Lady BeastDerek DrexlJackie Jewel', "Max Lords clones SuperNova, leading to a clash. Blue Bird lacks serum, while Komodo controls her poison for Vixen's agenda. Metal Skull aims to corrupt Marvel Girl using her weakness, pitting heroes against villainous forces.", 'Acción', '1h 13min', 'Super Vixens 6') Vamos por la iteración: 252
# La tupla de la peli Gaddar no está completa: (None, 'Nehal Dutta', 'Aruna BiswasNadimul IslamRittika Sen', '', 'Acción', None, 'Gaddar') Vamos por la iteración: 253
# Hemos añadido la peli Zoloto Umalty a la lista sin tomatometer. Vamos por la iteración: 254.
# La tupla de la peli The Crimson Knights no está completa: (None, '21%', 'Rayaan Yawar', 'Rayaan Yawar', 'A sadistic murderer named Smiler starts a chain of murders as two young Crimson Knights begin investigating the murders to find Smiler, An unfortunate chain of events causes them to be hunted down by the ruthless Crimson Hunter.', 'Acción', None, 'The Crimson Knights') Vamos por la iteración: 255
# ...
# La tupla de la peli The LGBTQ+ Films: Q no está completa: (None, None, None, None, None, None, 'The LGBTQ+ Films: Q') Vamos por la iteración: 382
# La tupla de la peli The LGBTQ+ Films: G no está completa: (None, 'Danny Thykær', 'Albert BendixDanny Thykær', 'Gregers is getting ready for a hookup with Noah in his apartment It is the first time they meet. Everything starts out perfectly, they kiss, but a misunderstanding causes the night to end in a way none of the two men had anticipated.', 'Corto', None, 'The LGBTQ+ Films: G') Vamos por la iteración: 383
# La tupla de la peli Broono no está completa: (None, 'Gerald Lepkowski', 'Gerald Lepkowski', 'In 1970s Glasgow, an unlikely friendship develops between a bereaved 11-year old lad and the local bully.', 'Corto', None, 'Broono') Vamos por la iteración: 384
# La tupla de la peli The Dream Fisher no está completa: (None, 'Roberto Valdés', 'Roberto Valdés', 'An introspective journey into the mind of a filmmaker in love.', 'Comedia\nDrama\nRomance', None, 'The Dream Fisher') Vamos por la iteración: 385
# La tupla de la peli Should Have Waited no está completa: (None, 'Peter Tyrrell', 'Peter Tyrrell', "Paul is a happy, caring family man who enjoys his time with his family and best friend. When his world suddenly comes crashing down around him, limits are tested. Can Paul find a way out of his situation before it's too late?", 'Drama', '1h 47min', 'Should Have Waited') Vamos por la iteración: 386
# La tupla de la peli The Satire no está completa: (None, 'Hussain Ahmad', 'Hussain Ahmad', 'El periodista Shamal sorprende al mundo al revelar un oscuro secreto', 'Comedia', '1h 25min', 'The Satire') Vamos por la iteración: 387
# La tupla de la peli Our Family Pride no está completa: (None, '100%', None, None, None, None, None, 'Our Family Pride') Vamos por la iteración: 388
# Hemos añadido la peli The Donor a la lista completa. Vamos por la iteración: 389.
# Hemos añadido la peli Del revés 2 (Inside Out 2) a la lista sin tomatometer. Vamos por la iteración: 390.
# Hemos añadido la peli Cem Karaca'nin Gözyaslari a la lista sin tomatometer. Vamos por la iteración: 391.
# Hemos añadido la peli Lal Salaam a la lista completa. Vamos por la iteración: 392.
# Hemos añadido la peli Onegin a la lista completa. Vamos por la iteración: 393.
# La tupla de la peli Yolun Sonu Nebi no está completa: (None, None, None, None, None, None, 'Yolun Sonu Nebi') Vamos por la iteración: 394
# La tupla de la peli Agent Narasimha-117 no está completa: (None, 'Lakshman Chaprala', 'DevgilHarshal GireKeerthi Krishna', "Budget joins a zamindar's house as a maid but becomes a villain. A girl is tied up in a dark room to look for a necklace and later tortured for it. The house is then termed 'Bhoot Bungalow'.", 'Acción', '2h 24min', 'Agent Narasimha-117') Vamos por la iteración: 395
# Hemos añadido la peli Hayatla Baris a la lista sin tomatometer. Vamos por la iteración: 396.
# La tupla de la peli None no está completa: (None, None, None, None, None, None, None) Vamos por la iteración: 397
# No se encontró el elemento de búsqueda para la película Dobrodosli doma con ID tt25864596.Vamos por la iteración: 398.
# La tupla de la peli Theo's Tears no está completa: (None, 'Jeremy Shinder', 'Jeremy Shinder', "With his mother away for business during the week of Halloween, Theo Kingston must combat his father's outdated and flawed conceptions of masculinity alone.", 'Corto', None, "Theo's Tears") Vamos por la iteración: 399
# La tupla de la peli Pangaa Gang no está completa: (None, 'Pankaj Sharma', 'Pankaj Sharma', "The movie is set in modern times, in a beautiful place called Shantivan. The story follows the adventures of four kids with extraordinary powers as they set out to defend their homeland from unwelcome intruders. 'Pangaa Gang' traces the action-packed journey of Seven friends as they battle evil forces to protect their beautiful homeland from deforestation and also sav... Leer todo", 'Animación', '1h 34min', 'Pangaa Gang') Vamos por la iteración: 400
# Hemos añadido la peli Opération Casablanca a la lista completa. Vamos por la iteración: 401.
# Hemos añadido la peli Death Calls a la lista sin tomatometer. Vamos por la iteración: 402.
# Hemos añadido la peli The Final Storm a la lista sin tomatometer. Vamos por la iteración: 403.
# Hemos añadido la peli Matad al héroe a la lista sin tomatometer. Vamos por la iteración: 404.
# Hemos añadido la peli Fast Lane a la lista sin tomatometer. Vamos por la iteración: 405.
# Hemos añadido la peli Nokas a la lista sin tomatometer. Vamos por la iteración: 406.
# Hemos añadido la peli La fortaleza Brest a la lista sin tomatometer. Vamos por la iteración: 407.
# Hemos añadido la peli Nude Nuns with Big Guns a la lista sin tomatometer. Vamos por la iteración: 408.
# La tupla de la peli Ultra no está completa: (None, None, None, None, None, '16min', 'Ultra') Vamos por la iteración: 409
# La tupla de la peli Jaljala no está completa: (None, 'Shivaji Lamichhane', 'Rekha Thapa', '', 'Acción', None, 'Jaljala') Vamos por la iteración: 410
# Hemos añadido la peli Origen a la lista completa. Vamos por la iteración: 411.
# Hemos añadido la peli Freight a la lista sin tomatometer. Vamos por la iteración: 412.
# Hemos añadido la peli Forged a la lista sin tomatometer. Vamos por la iteración: 413.
# Hemos añadido la peli Vaya par de polis a la lista sin tomatometer. Vamos por la iteración: 414.
# Hemos añadido la peli Los muertos a la lista sin tomatometer. Vamos por la iteración: 415.
# Hemos añadido la peli Baseline a la lista sin tomatometer. Vamos por la iteración: 416.
# Hemos añadido la peli Once Upon a Time in Mumbaai a la lista sin tomatometer. Vamos por la iteración: 417.
# Hemos añadido la peli Zatôichi: The Last a la lista sin tomatometer. Vamos por la iteración: 418.
# Hemos añadido la peli Rage a la lista completa. Vamos por la iteración: 419.
# La tupla de la peli Six Days in Paradise no está completa: ('6,3', 'John Vidor', 'Kala AlexanderTito FuegoJohn Vidor', 'A reformed gambler searching for his ex-wife and daughter; an amateur private-eye he hires; an assassin on a mission, and; a recruiter of mixed-martial arts fighters. Their lives intertwine when they come to Hawaii to accomplish their respective objectives. Rich McShane has overcome issues which years earlier served to extricate him from his wife and kid. He now wants... Leer todo', 'Acción', None, 'Six Days in Paradise') Vamos por la iteración: 420
# Hemos añadido la peli Twelve a la lista completa. Vamos por la iteración: 421.
# Hemos añadido la peli 13Hrs a la lista sin tomatometer. Vamos por la iteración: 422.
# La tupla de la peli Deyueru masutazu en no kizuna XX no está completa: (None, 'Keidai Hattori', 'Katsurô Hidaka', '', 'Animación', None, 'Deyueru masutazu en no kizuna XX') Vamos por la iteración: 423
# Hemos añadido la peli Tracker a la lista completa. Vamos por la iteración: 424.
# Hemos añadido la peli Predators a la lista sin tomatometer. Vamos por la iteración: 425.
# La tupla de la peli Money to Burn no está completa: ('6,5', None, None, None, None, None, 'Money to Burn') Vamos por la iteración: 426
# Hemos añadido la peli Unrivaled a la lista sin tomatometer. Vamos por la iteración: 427.
# Hemos añadido la peli Coursier a la lista sin tomatometer. Vamos por la iteración: 428.
# Hemos añadido la peli No Problem a la lista sin tomatometer. Vamos por la iteración: 429.
# Hemos añadido la peli 13 asesinos a la lista sin tomatometer. Vamos por la iteración: 430.
# La tupla de la peli Zombies & Cornbread no está completa: (None, 'Brandon Phillips', 'Jack ArmstrongBrandon Phillips', '"Zombies and Cornbread" - a tale of some good ol\' boys and zombies.', 'Corto', '10min', 'Zombies & Cornbread') Vamos por la iteración: 431
# Hemos añadido la peli Le ultime 56 ore a la lista sin tomatometer. Vamos por la iteración: 432.
# Hemos añadido la peli El americano a la lista completa. Vamos por la iteración: 433.
# Hemos añadido la peli 14 espadas a la lista completa. Vamos por la iteración: 434.
# Hemos añadido la peli Entre la ley y la calle a la lista sin tomatometer. Vamos por la iteración: 435.
# Hemos añadido la peli Devil's Playground a la lista completa. Vamos por la iteración: 436.
# Hemos añadido la peli Caribbean Basterds a la lista sin tomatometer. Vamos por la iteración: 437.
# Hemos añadido la peli Boy Wonder a la lista sin tomatometer. Vamos por la iteración: 438.
# Hemos añadido la peli Mañana, cuando la guerra empiece a la lista sin tomatometer. Vamos por la iteración: 439.
# La tupla de la peli Hunter's Moon no está completa: (None, None, None, None, None, '9min', "Hunter's Moon") Vamos por la iteración: 440
# Hemos añadido la peli Enemies Among Us a la lista sin tomatometer. Vamos por la iteración: 441.
# Hemos añadido la peli Outrage a la lista completa. Vamos por la iteración: 442.
# Hemos añadido la peli The Weathered Underground a la lista completa. Vamos por la iteración: 443.
# Hemos añadido la peli Confession a la lista sin tomatometer. Vamos por la iteración: 444.
# La tupla de la peli Cinco minutos para medianoche no está completa: (None, 'Fernando Guillén Cuervo', 'Fernando Guillén Cuervo', '20 men and women hide trying to protect themselves from a nuclear war. Each one of them have to face the final last five minutes of human being.', 'Corto', '6min', 'Cinco minutos para medianoche') Vamos por la iteración: 445
# Hemos añadido la peli Bear a la lista completa. Vamos por la iteración: 446.
# Hemos añadido la peli MacGruber a la lista completa. Vamos por la iteración: 447.
# La tupla de la peli Good Guys, Inc. no está completa: (None, '36%', None, None, None, None, '12min', 'Good Guys, Inc.') Vamos por la iteración: 448
# Hemos añadido la peli Space Battleship Yamato a la lista sin tomatometer. Vamos por la iteración: 449.
# Hemos añadido la peli Transparency a la lista completa. Vamos por la iteración: 450.
# Hemos añadido la peli Asal a la lista sin tomatometer. Vamos por la iteración: 451.
# Hemos añadido la peli Get Some a la lista sin tomatometer. Vamos por la iteración: 452.
# La tupla de la peli Officer Lenot in: Showtime no está completa: (None, None, None, None, None, '19min', 'Officer Lenot in: Showtime') Vamos por la iteración: 453
# Hemos añadido la peli Trap a la lista sin tomatometer. Vamos por la iteración: 454.
# Hemos añadido la peli Paiyaa a la lista sin tomatometer. Vamos por la iteración: 455.
# Hemos añadido la peli Dead Cert a la lista sin tomatometer. Vamos por la iteración: 456.
# La tupla de la peli Courier no está completa: (None, '85%', None, None, None, None, '1h 36min', 'Courier') Vamos por la iteración: 457
# La tupla de la peli Hard Way Heroes no está completa: (None, '75%', None, None, None, None, None, 'Hard Way Heroes') Vamos por la iteración: 458
# La tupla de la peli In III Dragon no está completa: (None, '90%', None, None, None, None, '1h 55min', 'In III Dragon') Vamos por la iteración: 459
# La tupla de la peli VideoDome Rent-O-Rama no está completa: ('5,3', None, None, None, None, '41min', 'VideoDome Rent-O-Rama') Vamos por la iteración: 460
# La tupla de la peli Burning Stage no está completa: (None, None, None, None, None, '4min', 'Burning Stage') Vamos por la iteración: 461
# Hemos añadido la peli Headwound a la lista sin tomatometer. Vamos por la iteración: 462.
# La tupla de la peli The Grind no está completa: ('6,3', 'Jhon Doria', 'Jhon DoriaJoe Greto', '', 'Acción', None, 'The Grind') Vamos por la iteración: 463
# Hemos añadido la peli Super a la lista sin tomatometer. Vamos por la iteración: 464.
# Hemos añadido la peli Carpet Racers a la lista sin tomatometer. Vamos por la iteración: 465.
# Hemos añadido la peli Terrible Things a la lista completa. Vamos por la iteración: 466.
# La tupla de la peli The Sierra no está completa: (None, 'A.D. Massi', 'A.D. Massi', "The air ain't all that's cold in the Sierra Nevada, especially just outside of 19th Century Virginia City, Nevada. For this is where the lives of a Native American couple collide with a ruthless gang. They seek revenge upon two brothers who interrupted their train robbery and escaped with the cash. The head outlaw leads his men into the snowy wilderness to finish off ... Leer todo", 'Corto', '28min', 'The Sierra') Vamos por la iteración: 467
# Hemos añadido la peli Karl the Butcher vs Axe a la lista sin tomatometer. Vamos por la iteración: 468.
# La tupla de la peli Black Ops Arabesque no está completa: ('4,9', None, None, None, None, '5min', 'Black Ops Arabesque') Vamos por la iteración: 469
# Hemos añadido la peli Couch a la lista sin tomatometer. Vamos por la iteración: 470.
# La tupla de la peli 9 AM no está completa: (None, None, None, None, None, '9min', '9 AM') Vamos por la iteración: 471
# Hemos añadido la peli The Diamonds of Metro Valley a la lista sin tomatometer. Vamos por la iteración: 472.
# Hemos añadido la peli Broken Springs a la lista sin tomatometer. Vamos por la iteración: 473.
# La tupla de la peli Shop Secret no está completa: ('8,6', None, None, None, None, '15min', 'Shop Secret') Vamos por la iteración: 474
# Hemos añadido la peli Pedaço de Papel a la lista sin tomatometer. Vamos por la iteración: 475.
# Hemos añadido la peli Carpe Millennium a la lista sin tomatometer. Vamos por la iteración: 476.
# Hemos añadido la peli Gantz a la lista sin tomatometer. Vamos por la iteración: 477.
# Hemos añadido la peli El hombre sin pasado a la lista sin tomatometer. Vamos por la iteración: 478.
# Hemos añadido la peli Disrupt/Dismantle a la lista sin tomatometer. Vamos por la iteración: 479.
# Hemos añadido la peli Route Irish a la lista sin tomatometer. Vamos por la iteración: 480.
# Hemos añadido la peli Nacido para matar a la lista sin tomatometer. Vamos por la iteración: 481.
# La tupla de la peli Szinglik éjszakája no está completa: ('2,4', 'Tamás Sas', 'András Kovács M.Péter SzajkiNóra Zsigmond', '', 'Acción', None, 'Szinglik éjszakája') Vamos por la iteración: 482
# Hemos añadido la peli Fight or Flight a la lista sin tomatometer. Vamos por la iteración: 483.
# La tupla de la peli Pangaa Gang no está completa: (None, 'Pankaj Sharma', 'Pankaj Sharma', "The movie is set in modern times, in a beautiful place called Shantivan. The story follows the adventures of four kids with extraordinary powers as they set out to defend their homeland from unwelcome intruders. 'Pangaa Gang' traces the action-packed journey of Seven friends as they battle evil forces to protect their beautiful homeland from deforestation and also sav... Leer todo", 'Animación', '1h 34min', 'Pangaa Gang') Vamos por la iteración: 484
# Hemos añadido la peli La saga Crepúsculo: Eclipse a la lista sin tomatometer. Vamos por la iteración: 485.
# Hemos añadido la peli Opération Casablanca a la lista completa. Vamos por la iteración: 486.
# La tupla de la peli War Torn no está completa: (None, None, None, None, None, '3min', 'War Torn') Vamos por la iteración: 487
# Hemos añadido la peli Death Calls a la lista sin tomatometer. Vamos por la iteración: 488.
# Hemos añadido la peli Bold Native a la lista sin tomatometer. Vamos por la iteración: 489.
# Hemos añadido la peli The Final Storm a la lista sin tomatometer. Vamos por la iteración: 490.
# Hemos añadido la peli La isla de los olvidados a la lista completa. Vamos por la iteración: 491.
# Hemos añadido la peli Matad al héroe a la lista sin tomatometer. Vamos por la iteración: 492.
# Hemos añadido la peli Raavan a la lista sin tomatometer. Vamos por la iteración: 493.
# Hemos añadido la peli Fast Lane a la lista sin tomatometer. Vamos por la iteración: 494.
# Hemos añadido la peli The Wylds a la lista completa. Vamos por la iteración: 495.
# Hemos añadido la peli Nokas a la lista sin tomatometer. Vamos por la iteración: 496.
# Hemos añadido la peli Mei loi ging chat a la lista sin tomatometer. Vamos por la iteración: 497.
# Hemos añadido la peli La fortaleza Brest a la lista sin tomatometer. Vamos por la iteración: 498.
# La tupla de la peli El Banco no está completa: (None, None, None, None, None, None, 'El Banco') Vamos por la iteración: 499
# Hemos añadido la peli Nude Nuns with Big Guns a la lista sin tomatometer. Vamos por la iteración: 500.

# %%
len(resultados_sin_tomatometer)
# Out:
# 149

# %%
len(resultados_completos)
# Out:
# 35

# %%
not_found
# Out:
# []

# %%
# Se tarda aproximadamente 33 minutos para extraer 50 peliculas.
# Se tarda aproximadamente 67 minutos para extraer 100 peliculas.

# %%
# Guardar los datos de manera permanente
df_resultados_completos = pd.DataFrame(resultados_completos)
df_resultados_sin_tomatometer = pd.DataFrame(resultados_sin_tomatometer)
df_errores = pd.DataFrame(not_found)
df_resultados_completos.to_csv('resultados_completos_F2_laura_3000-3500.csv') # Cambiar nombre !!! 
df_resultados_sin_tomatometer.to_csv('resultados_sin_tomatometer_F2_laura_3000-3500.csv')
df_errores.to_csv('errores_F2_laura_100-150_1000-2000_3000-3500.csv')
df_resultados_completos.to_json('resultados_completos_F2_laura_3000-35000.json') 
df_resultados_sin_tomatometer.to_json('resultados_sin_tomatometer_F2_laura_3000-3500.json')
df_errores.to_json('errores_F2_laura_laura_3000-3500.json')

# %%
df_resultados_sin_tomatometer
# Out:
#        0     1                  2  \
# 0    5,8  None      Michael Maren
# 1    7,0  None          Paul King
# 2    5,8  None  Dmitriy Dyachenko
# 3    7,9  None         James Gunn
# 4    3,6  None       Marja Pyykkö
# ..   ...   ...                ...
# 144  3,3  None     David Betances
# 145  6,4  None   Erik Skjoldbjærg
# 146  3,5  None          Jing Wong
# 147  7,4  None     Aleksandr Kott
# 148  3,9  None      Joseph Guzman
#
#                                                      3  \
# 0                                        Michael Maren
# 1                                           Roald Dahl
# 2                                     Vasiliy Kutsenko
# 3                                           James Gunn
# 4                                        Misa Palander
# ..                                                 ...
# 144                        David BetancesSevier Crespo
# 145                               Christopher Grøndahl
# 146                                          Jing Wong
# 147  Aleksey DudarevVladimir EryominEkaterina Tirda...
# 148                                      Joseph Guzman
#
#                                                      4  \
# 0    Cuando un manitas que vive en Nueva York es co...
# 1    La historia se centrará específicamente en un ...
# 2    What if Cheburashka really exists? What if he ...
# 3    Todavía conmocionado por la pérdida de Gamora,...
# 4    Four friends who have visited different ski re...
# ..                                                 ...
# 144  A high-speed accident on the freeways of Los A...
# 145  The movie portrays Norway's most spectacular r...
# 146  A cop travels back in time to take on a corpor...
# 147  A war drama set during the Nazi invasion of th...
# 148  Abusada mentalmente, esclavizada y forzada a l...
#
#                                5         6                                7
# 0                        Comedia  1h 41min              Una pequeña mentira
# 1    Aventura\nComedia\nFamiliar  1h 56min                            Wonka
# 2              Comedia\nFamiliar  1h 53min                      Cheburashka
# 3      Acción\nAventura\nComedia  2h 30min  Guardianes de la Galaxia Vol. 3
# 4                        Comedia  1h 25min                      Skimbagirls
# ..                           ...       ...                              ...
# 144                       Acción  1h 14min                        Fast Lane
# 145                       Acción  1h 27min                            Nokas
# 146                       Acción  1h 39min                Mei loi ging chat
# 147                       Acción  2h 18min               La fortaleza Brest
# 148    Acción\nComedia\nSuspense  1h 31min          Nude Nuns with Big Guns
#
# [149 rows x 8 columns]

# %%
df_errores
# Out:
#                                                       0
# 0     No hay tomatometer para la peli Una pequeña me...
# 1     Faltan datos de imdb para la peli: Murdock by ...
# 2     No hay tomatometer para la peli The Hard Time ...
# 3     No hay tomatometer para la peli Wonka con id_i...
# 4     Faltan datos de imdb para la peli: Murdock by ...
# ...                                                 ...
# 1266  Faltan datos de imdb para la peli: Murdock by ...
# 1267  Faltan datos de imdb para la peli: Murdock by ...
# 1268  Faltan datos de imdb para la peli: Murdock by ...
# 1269  No hay tomatometer para la peli El Banco con i...
# 1270  No hay tomatometer para la peli Nude Nuns with...
#
# [1271 rows x 1 columns]

# %%
df_resultados_completos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_resultados_completos
#
# NameError: name 'df_resultados_completos' is not defined

# %%
# Puntuacion de IMDB (en caso de que la tenga).

# Puntuación de Rotten Tomatoes (Tomatometer).

# Dirección (director/a o directore/as de cada película).

# Gionistas (de cada película).

# Argumento.

# Duración. >> Tal cuál está 

# Nombre de la película

# Genero !!! 

# NOTA: La información de la API deberá ser almacenada en una lista de tuplas. Cada tupla corresponderá a una película. Siguiendo el siguiente ejemplo:

# [(7.7, 77, "Richard Donner", ["Chris ColumbusSteven", "Spielberg"], "Los Goonies son un grupo de amigos que viven en Goon Docks, Astoria, pero sus casas han sido compradas y van a ser demolidas. Sin embargo, vivirán su última aventura en busca de un tesoro que pueda salvar el barrio.", "Aventura", "1h 54min", "Los Gonnies"), ...]

# %%
import os

# Directorio donde se encuentran los archivos CSV
directorio = 'CSV_JSON_F2'

# Lista para almacenar los dataframes
dataframes = []

# Iterar sobre todos los archivos en el directorio
for archivo in os.listdir(directorio):
    if archivo.endswith('.csv'):
        # Leer cada archivo CSV
        df = pd.read_csv(os.path.join(directorio, archivo))
        # Añadir el dataframe a la lista
        dataframes.append(df)

# Combinar todos los dataframes en uno solo
df_combinado = pd.concat(dataframes, ignore_index=True)

# Guardar el dataframe combinado en un nuevo archivo CSV
df_combinado.to_csv('CSV_JSON_F2/F2_combinado.csv', index=False)

print("Archivos CSV combinados con éxito.")
# Out:
# Archivos CSV combinados con éxito.

# %%
len(df_combinado)
# Out:
# 241
