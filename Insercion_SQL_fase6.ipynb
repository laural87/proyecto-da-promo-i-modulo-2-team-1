# %%
# Importar librería para la conexión con MySQL
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np


# importamos las librerías que necesitaremos
# Importar librería para trabajar con archivos JSON
# -----------------------------------------------------------------------
import json
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
#leemos el csv

df_oscars = pd.read_csv("CSV_JSON_F4/lista_tuplas_fase4.csv", index_col = 0)

#Hacemos una lista con el nombre de las columnas actuales del data frame
columnas_actuales = df_oscars.columns.tolist()

#Definimos el nombre de las columnas
nuevos_nombres = ['FechaCeremonia', 'MejorPelicula', 'MejorDirector', 'MejorActor', 'MejorActriz']

#Cambiamos el nombre de las columnas por la lista que hemos creado
df_oscars.columns = nuevos_nombres

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='moviemakers')
mycursor = cnx.cursor()



#Iteramos por cada uno de los elementos

for index, row in df_oscars.iterrows():
    sql = """
        INSERT INTO Oscars (FechaCeremonia, MejorPelicula, MejorDirector, MejorActor, MejorActriz) 
        VALUES ( %s, %s, %s, %s, %s)
    """
    values = (row['FechaCeremonia'], row['MejorPelicula'], row['MejorDirector'], row['MejorActor'], row['MejorActriz'])
    
    try:
        mycursor.execute(sql, values)
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# Confirmar la inserción
cnx.commit()

print(f'Se han insertado los datos correctamente')
# Cerrar conexión
mycursor.close()
cnx.close()
# Out:
# Se han insertado los datos correctamente

# %%
#leemos el csv

df_peliculas = pd.read_csv("CSV_JSON_F4/lista_tuplas_fase4.csv", index_col = 0)  #cambiar el nombre del archivo

#Hacemos una lista con el nombre de las columnas actuales del data frame
columnas_actuales = df_peliculas.columns.tolist()

#Definimos el nombre de las columnas
nuevos_nombres = ['Tipo', 'Nombre', 'AnioEstreno', 'MesEstreno', 'IdPelicula']

#Cambiamos el nombre de las columnas por la lista que hemos creado
df_peliculas.columns = nuevos_nombres

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='moviemakers')
mycursor = cnx.cursor()



#Iteramos por cada uno de los elementos

for index, row in df_peliculas.iterrows():           
    sql = """
        INSERT INTO Peliculas (Tipo, Nombre, AnioEstreno, MesEstreno, IdPelicula) 
        VALUES ( %s, %s, %s, %s, %s)
    """
    values = (row['Tipo'], row['Nombre'], row['AnioEstreno'], row['MesEstreno'], row['IdPelicula'])
    
    try:
        mycursor.execute(sql, values)
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# Confirmar la inserción
cnx.commit()

print(f'Se han insertado los datos correctamente')
# Cerrar conexión
mycursor.close()
cnx.close()

# %%
#leemos el csv

df_caracteristicas_peliculas = pd.read_csv("CSV_JSON_F4/lista_tuplas_fase4.csv", index_col = 0)  #cambiar el nombre del archivo

#Hacemos una lista con el nombre de las columnas actuales del data frame
columnas_actuales = df_caracteristicas_peliculas.columns.tolist()

#Definimos el nombre de las columnas
nuevos_nombres = ['IdPelicula', 'PuntuacionIMDB', 'PuntuacionTomatoes', 'Directores', 'Guionistas', 'Genero', 'DuracionMinutos']

#Cambiamos el nombre de las columnas por la lista que hemos creado
df_caracteristicas_peliculas.columns = nuevos_nombres

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='moviemakers')
mycursor = cnx.cursor()



#Iteramos por cada uno de los elementos

for index, row in df_caracteristicas_peliculas.iterrows():           
    sql = """
        INSERT INTO Peliculas_caracteristicas (IdPelicula, PuntuacionIMDB, PuntuacionTomatoes, Directores, Guionistas, Genero, DuracionMinutos) 
        VALUES ( %s, %s, %s, %s, %s, %s, %s)
    """
    values = (row['IdPelicula'], row['PuntuacionIMDB'], row['PuntuacionTomatoes'], row['Directores'], row['Guionistas'], row['Genero'], row['DuracionMinutos'] )
    
    try:
        mycursor.execute(sql, values)
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# Confirmar la inserción
cnx.commit()

print(f'Se han insertado los datos correctamente')
# Cerrar conexión
mycursor.close()
cnx.close()

# %%
#leemos el csv

df_actores = pd.read_csv("prueba_insercion_sin_duplicados.csv", index_col=0)  #cambiar el nombre del archivo

# %%
#Hacemos una lista con el nombre de las columnas actuales del data frame
columnas_actuales = df_actores.columns.tolist()

#Definimos el nombre de las columnas
nuevos_nombres = ['Nombre', 'AnioNacimiento', 'ConocidoPor', 'ActividadActual', 'Premios']

#Cambiamos el nombre de las columnas por la lista que hemos creado
df_actores.columns = nuevos_nombres

# %%
df_actores.columns
# Out:
# Index(['Nombre', 'AnioNacimiento', 'ConocidoPor', 'ActividadActual',
#        'Premios'],
#       dtype='object')

# %%
df_actores
# Out:
#                Nombre  AnioNacimiento  \
# 0
# 1      David Arquette            1971
# 2           Amy Smart            1976
# 3      Frances Fisher            1952
# 4    Mariel Hemingway            1961
# 5        Irene Bedard            1967
# ..                ...             ...
# 100    Robert LaSardo            1963
# 101       Rajinikanth            1950
# 102     Vishnu Vishal            1984
# 103    K.S. Ravikumar            1958
# 104    Thambi Ramaiah            1956
#
#                                            ConocidoPor  \
# 0
# 1    ['Scream 3', 'Nunca me han besado', 'Scream 2'...
# 2    ['Starship Troopers (Las brigadas del espacio)...
# 3    ['Titanic', 'Sin perdón', 'Amor de calendario'...
# 4    ['Manhattan', 'Superman IV: En busca de la paz...
# 5    ['Pocahontas', 'Ralph rompe Internet', 'Into t...
# ..                                                 ...
# 100  ['Mula', 'Death Race: La carrera de la muerte'...
# 101            ['Enthiran', 'Sivaji', '2.0', 'Kabali']
# 102  ['Ratsasan', 'Vennila Kabadi Kuzhu', 'Neer Par...
# 103  ['Dasavatharam', 'Padayappa', 'Varalaaru', 'Na...
# 104     ['Mynaa', 'Thani Oruvan', 'Kumki', 'Thalaivi']
#
#                                    ActividadActual  \
# 0
# 1           ['Producción', 'Reparto', 'Dirección']
# 2                      ['Reparto', 'Banda sonora']
# 3             ['Reparto', 'Cámara y electricidad']
# 4    ['Reparto', 'Producción', 'Equipo ejecutivo']
# 5                        ['Reparto', 'Producción']
# ..                                             ...
# 100             ['Reparto', 'Producción', 'Guion']
# 101             ['Reparto', 'Guion', 'Producción']
# 102                      ['Reparto', 'Producción']
# 103              ['Reparto', 'Dirección', 'Guion']
# 104              ['Reparto', 'Dirección', 'Guion']
#
#                                                Premios
# 0
# 1    ['Blockbuster Entertainment Awards Gan', 'Brec...
# 2    ['MTV Movie + TV Awards Gan', 'Teen Choice Awa...
# 3    ['Screen Actors Guild Awards Nom', 'Chlotrudis...
# 4    ['Academy Awards USA Nom', 'BAFTA Awards Nom',...
# 5    ['Golden Globes USA Nom', 'NAMIC Vision Awards...
# ..                                                 ...
# 100  ['Accolade Competition Gan', 'Hollywood Blood ...
# 101  ['National Film Awards India Gan', 'Internatio...
# 102  ['South Indian International Movie Awards Nom'...
# 103  ['Filmfare Awards South Nom', 'South Indian In...
# 104  ['National Film Awards India Gan', 'Filmfare A...
#
# [103 rows x 5 columns]

# %%
df = df_actores.drop(index=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df = df_actores.drop(index=0)
#
# File c:\Users\yamia\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File c:\Users\yamia\anaconda3\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\yamia\anaconda3\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\yamia\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: '[0] not found in axis'

# %%
df
# Out:
#                Nombre  AnioNacimiento  \
# 0
# 1      David Arquette            1971
# 2           Amy Smart            1976
# 3      Frances Fisher            1952
# 4    Mariel Hemingway            1961
# 5        Irene Bedard            1967
# ..                ...             ...
# 100    Robert LaSardo            1963
# 101       Rajinikanth            1950
# 102     Vishnu Vishal            1984
# 103    K.S. Ravikumar            1958
# 104    Thambi Ramaiah            1956
#
#                                            ConocidoPor  \
# 0
# 1    ['Scream 3', 'Nunca me han besado', 'Scream 2'...
# 2    ['Starship Troopers (Las brigadas del espacio)...
# 3    ['Titanic', 'Sin perdón', 'Amor de calendario'...
# 4    ['Manhattan', 'Superman IV: En busca de la paz...
# 5    ['Pocahontas', 'Ralph rompe Internet', 'Into t...
# ..                                                 ...
# 100  ['Mula', 'Death Race: La carrera de la muerte'...
# 101            ['Enthiran', 'Sivaji', '2.0', 'Kabali']
# 102  ['Ratsasan', 'Vennila Kabadi Kuzhu', 'Neer Par...
# 103  ['Dasavatharam', 'Padayappa', 'Varalaaru', 'Na...
# 104     ['Mynaa', 'Thani Oruvan', 'Kumki', 'Thalaivi']
#
#                                    ActividadActual  \
# 0
# 1           ['Producción', 'Reparto', 'Dirección']
# 2                      ['Reparto', 'Banda sonora']
# 3             ['Reparto', 'Cámara y electricidad']
# 4    ['Reparto', 'Producción', 'Equipo ejecutivo']
# 5                        ['Reparto', 'Producción']
# ..                                             ...
# 100             ['Reparto', 'Producción', 'Guion']
# 101             ['Reparto', 'Guion', 'Producción']
# 102                      ['Reparto', 'Producción']
# 103              ['Reparto', 'Dirección', 'Guion']
# 104              ['Reparto', 'Dirección', 'Guion']
#
#                                                Premios
# 0
# 1    ['Blockbuster Entertainment Awards Gan', 'Brec...
# 2    ['MTV Movie + TV Awards Gan', 'Teen Choice Awa...
# 3    ['Screen Actors Guild Awards Nom', 'Chlotrudis...
# 4    ['Academy Awards USA Nom', 'BAFTA Awards Nom',...
# 5    ['Golden Globes USA Nom', 'NAMIC Vision Awards...
# ..                                                 ...
# 100  ['Accolade Competition Gan', 'Hollywood Blood ...
# 101  ['National Film Awards India Gan', 'Internatio...
# 102  ['South Indian International Movie Awards Nom'...
# 103  ['Filmfare Awards South Nom', 'South Indian In...
# 104  ['National Film Awards India Gan', 'Filmfare A...
#
# [103 rows x 5 columns]

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='moviemakers')
mycursor = cnx.cursor()



#Iteramos por cada uno de los elementos

for index, row in df_actores.iterrows():           
    sql = """
        INSERT INTO Peliculas_caracteristicas (Nombre, AnioNacimiento, ConocidoPors, ActividadActual, Premios) 
        VALUES ( %s, %s, %s, %s, %s)
    """
    values = (row['Nombre'], row['AnioNacimiento'], row['ConocidoPor'], row['ActividadActual'], row['Premios'])
    
    try:
        mycursor.execute(sql, values)
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# Confirmar la inserción
cnx.commit()

print(f'Se han insertado los datos correctamente')
# Cerrar conexión
mycursor.close()
cnx.close()
# Out:
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Error: 1054 (42S22): Unknown column 'Nombre' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'Nombre' in 'field list'
# Se han insertado los datos correctamente

# %%
#leemos el csv

df_actuaciones = pd.read_csv("CSV_JSON_F4/lista_tuplas_fase4.csv", index_col = 0)  #cambiar el nombre del archivo

#Hacemos una lista con el nombre de las columnas actuales del data frame
columnas_actuales = df_actuaciones.columns.tolist()

#Definimos el nombre de las columnas
nuevos_nombres = ['IdPelicula', 'NombreActor']

#Cambiamos el nombre de las columnas por la lista que hemos creado
df_actuaciones.columns = nuevos_nombres

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='moviemakers')
mycursor = cnx.cursor()



#Iteramos por cada uno de los elementos

for index, row in df_actuaciones.iterrows():           
    sql = """
        INSERT INTO Peliculas_caracteristicas (IdPelicula, NombreActor) 
        VALUES ( %s, %s)
    """
    values = (row['IdPelicula'], row['NombreActor'])
    
    try:
        mycursor.execute(sql, values)
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# Confirmar la inserción
cnx.commit()

print(f'Se han insertado los datos correctamente')
# Cerrar conexión
mycursor.close()
cnx.close()
