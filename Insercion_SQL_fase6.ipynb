# %%
# Importar librería para la conexión con MySQL
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np


# importamos las librerías que necesitaremos
# Importar librería para trabajar con archivos JSON
# -----------------------------------------------------------------------
import json
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %% [markdown]
# ## Insertamos datos tabla Oscars

# %%
#leemos el csv

df_oscars = pd.read_csv("CSV_JSON_F4/lista_tuplas_fase4.csv", index_col = 0)

#Hacemos una lista con el nombre de las columnas actuales del data frame
columnas_actuales = df_oscars.columns.tolist()

#Definimos el nombre de las columnas
nuevos_nombres = ['FechaCeremonia', 'MejorPelicula', 'MejorDirector', 'MejorActor', 'MejorActriz']

#Cambiamos el nombre de las columnas por la lista que hemos creado
df_oscars.columns = nuevos_nombres

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='moviemakers')
mycursor = cnx.cursor()



#Iteramos por cada uno de los elementos

for index, row in df_oscars.iterrows():
    sql = """
        INSERT INTO Oscars (FechaCeremonia, MejorPelicula, MejorDirector, MejorActor, MejorActriz) 
        VALUES ( %s, %s, %s, %s, %s)
    """
    values = (row['FechaCeremonia'], row['MejorPelicula'], row['MejorDirector'], row['MejorActor'], row['MejorActriz'])
    
    try:
        mycursor.execute(sql, values)
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# Confirmar la inserción
cnx.commit()

print(f'Se han insertado los datos correctamente')
# Cerrar conexión
mycursor.close()
cnx.close()
# Out:
# Se han insertado los datos correctamente

# %% [markdown]
# ## Insertamos datos tabla películas

# %%
#leemos el csv

df_peliculas = pd.read_csv("CSV_JSON_F1/resultado_tuplas_total.csv")  #cambiar el nombre del archivo

#Hacemos una lista con el nombre de las columnas actuales del data frame
columnas_actuales = df_peliculas.columns.tolist()

#Definimos el nombre de las columnas
nuevos_nombres = ['Tipo', 'Nombre', 'AnioEstreno', 'MesEstreno', 'IdPelicula']

#Cambiamos el nombre de las columnas por la lista que hemos creado
df_peliculas.columns = nuevos_nombres



#Combertimos en INT las columnas AnioEstreno y MesEstreno porque daba error de NAN Además convertimos el ano y mes en INT

df_peliculas['AnioEstreno'] = df_peliculas['AnioEstreno'].fillna(0).astype(int)
df_peliculas['MesEstreno'] = df_peliculas['MesEstreno'].fillna(0).astype(int)

#Eliminamos duplicados 
df_peliculas = df_peliculas.drop_duplicates()

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='moviemakers')
mycursor = cnx.cursor()



#Iteramos por cada uno de los elementos

for index, row in df_peliculas.iterrows():           
    sql = """
        INSERT INTO Peliculas (Tipo, Nombre, AnioEstreno, MesEstreno, IdPelicula) 
        VALUES ( %s, %s, %s, %s, %s)
    """
    values = (row['Tipo'], row['Nombre'], row['AnioEstreno'], row['MesEstreno'], row['IdPelicula'])
    
    try:
        mycursor.execute(sql, values)
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# Confirmar la inserción
cnx.commit()

print(f'Se han insertado los datos correctamente')
# Cerrar conexión
mycursor.close()
cnx.close()
# Out:
# Error: 1062 (23000): Duplicate entry 'tt29402528' for key 'peliculas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt29402528' for key 'peliculas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt29538571' for key 'peliculas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt29538571' for key 'peliculas.PRIMARY'
# Se han insertado los datos correctamente

# %% [markdown]
# ## Insertamos datos tabla caracteristicas películas

# %%
#leemos el csv

df_caracteristicas_peliculas = pd.read_csv("archivo_final_actualizado.csv")  #cambiar el nombre del archivo

#Hacemos una lista con el nombre de las columnas actuales del data frame
columnas_actuales = df_caracteristicas_peliculas.columns.tolist()

#Definimos el nombre de las columnas
nuevos_nombres = ['PuntuacionIMDB', 'PuntuacionTomatoes', 'Directores', 'Guionistas', 'Argumento', 'Genero', 'DuracionMinutos', 'Nombre', 'idPelicula']

#Cambiamos el nombre de las columnas por la lista que hemos creado
df_caracteristicas_peliculas.columns = nuevos_nombres

#Eliminamos duplicados 
df_caracteristicas_peliculas = df_caracteristicas_peliculas.drop_duplicates()

# cambiamos en el dataframe la , por . lo convertimos en float y quitomos los errorer Nan

df_caracteristicas_peliculas['PuntuacionIMDB'] = df_caracteristicas_peliculas['PuntuacionIMDB'].str.replace(',', '.')
df_caracteristicas_peliculas['PuntuacionIMDB'] = df_caracteristicas_peliculas['PuntuacionIMDB'].fillna('Null').astype(float)
df_caracteristicas_peliculas['PuntuacionTomatoes'] = df_caracteristicas_peliculas['PuntuacionTomatoes'].fillna('Null').astype(float)
df_caracteristicas_peliculas['Directores'] = df_caracteristicas_peliculas['Directores'].fillna('Null')
df_caracteristicas_peliculas['Guionistas'] = df_caracteristicas_peliculas['Guionistas'].fillna('Null')
df_caracteristicas_peliculas['Argumento'] = df_caracteristicas_peliculas['Argumento'].fillna('Null')
df_caracteristicas_peliculas['Genero'] = df_caracteristicas_peliculas['Genero'].fillna('Null')
df_caracteristicas_peliculas['DuracionMinutos'] = df_caracteristicas_peliculas['DuracionMinutos'].fillna('Null')
df_caracteristicas_peliculas['Nombre'] = df_caracteristicas_peliculas['Nombre'].fillna('Null')

# %%
df_caracteristicas_peliculas
# Out:
#      PuntuacionIMDB  PuntuacionTomatoes                        Directores  \
# 0               6.9                72.0                       Jon Favreau
# 1               6.0                21.0  Florian Henckel von Donnersmarck
# 2               7.0                72.0                  Robert Schwentke
# 3               7.6                77.0                    Matthew Vaughn
# 4               5.1                92.0                    Dolph Lundgren
# ..              ...                 ...                               ...
# 372             6.9               100.0                  Ainsley Gardiner
# 373             7.4                93.0                   Xavier Giannoli
# 374             6.7                90.0                          Leon Lee
# 375             5.4                73.0                    Oliver Milburn
# 376             7.3                84.0                    Scooter Powell
#
#                            Guionistas  \
# 0                      Justin Theroux
# 1    Florian Henckel von Donnersmarck
# 2                          Jon Hoeber
# 3                        Jane Goldman
# 4                         Raul Inglis
# ..                                ...
# 372                    Patricia Grace
# 373                   Xavier Giannoli
# 374                          Leon Lee
# 375                  Scott K. Andrews
# 376                  Rasheed Stephens
#
#                                              Argumento  \
# 0    Con el mundo sabiendo que es Iron Man, Tony St...
# 1    Frank es un turista estadounidense que visita ...
# 2    Cuando su pacífica vida se ve amenazada por un...
# 3    Dave Lizewski es un estudiante de instituto qu...
# 4    A Soviet-trained assassin is determined to esc...
# ..                                                 ...
# 372  Entwines the very different lives of three Mao...
# 373  Un joven poeta va en busca de fortuna con gran...
# 374  When the Chinese Communist Party launches a br...
# 375  A 15-year old flees to his school after an apo...
# 376  A betrayed married woman's life change in one ...
#
#                               Genero DuracionMinutos  \
# 0      ['Acción', 'Ciencia ficción']         2h 4min
# 1             ['Acción', 'Suspense']        1h 43min
# 2    ['Acción', 'Comedia', 'Crimen']        1h 51min
# 3    ['Acción', 'Comedia', 'Crimen']        1h 57min
# 4             ['Acción', 'Suspense']        1h 28min
# ..                               ...             ...
# 372                        ['Drama']        1h 38min
# 373             ['Drama', 'Romance']        2h 29min
# 374                        ['Drama']        1h 48min
# 375   ['Comedia', 'Drama', 'Terror']        1h 45min
# 376             ['Drama', 'Romance']        1h 23min
#
#                             Nombre  idPelicula
# 0                       Iron Man 2   tt1228705
# 1                      The Tourist   tt1243957
# 2                              RED   tt1245526
# 3    Kick-Ass: Listo para machacar         NaN
# 4                           Icarus   tt1261862
# ..                             ...         ...
# 372                        Cousins  tt10422498
# 373         Las ilusiones perdidas         NaN
# 374                     Unsilenced  tt10514056
# 375           School's Out Forever  tt10510280
# 376                Between Forever  tt10521244
#
# [377 rows x 9 columns]

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='moviemakers')
mycursor = cnx.cursor()



#Iteramos por cada uno de los elementos

for index, row in df_caracteristicas_peliculas.iterrows():           
    sql = """
        INSERT INTO Peliculas_caracteristicas (PuntuacionIMDB, PuntuacionTomatoes, Directores, Guionistas, Argumento, Genero, DuracionMinutos, Nombre, idPelicula) 
        VALUES ( %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """
    values = (row['PuntuacionIMDB'], row['PuntuacionTomatoes'], row['Directores'], row['Guionistas'], row['Argumento'], row['Genero'], row['DuracionMinutos'] , row['Nombre'], row['idPelicula'])
    
    try:
        mycursor.execute(sql, values)
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# Confirmar la inserción
cnx.commit()

print(f'Se han insertado los datos correctamente')
# Cerrar conexión
mycursor.close()
cnx.close()
# Out:
# Error: 1062 (23000): Duplicate entry 'tt1228705' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1228705' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1243957' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1243957' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1245526' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1245526' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt1261862' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1261862' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1262983' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1262983' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1270835' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1270835' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1272018' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1272018' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1305797' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1305797' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10004944' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10004944' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10038028' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10038028' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10009030' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10009030' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10011336' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10011336' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt10022384' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10022384' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt0810836' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0810836' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10300704' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10300704' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10308500' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10308500' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt15345308' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt15345308' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt10580094' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10580094' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10364308' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10364308' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10054316' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10054316' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt10077544' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10077544' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10100678' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10100678' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10111180' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10111180' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10126434' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10126434' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10260692' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10260692' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10280276' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10280276' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10023172' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10023172' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10023022' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10023022' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10032266' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10032266' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10039524' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10039524' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt3184520' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt3184520' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10065694' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10065694' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10102402' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10102402' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10110614' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10110614' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10132976' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10132976' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10147910' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10147910' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10151656' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10151656' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10152722' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10152722' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10161886' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10161886' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10183816' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10183816' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10189514' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10189514' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10198064' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10198064' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt0293429' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0293429' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10156586' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10156586' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10358782' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10358782' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10483386' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10483386' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11286210' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11286210' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10782740' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10782740' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt10469804' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10469804' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10888594' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10888594' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11242718' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11242718' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11260832' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11260832' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11306518' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11306518' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt11503178' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11503178' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11636880' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11636880' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11650226' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11650226' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt11762434' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11762434' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11799110' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11799110' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt0870154' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0870154' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10098288' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10098288' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt10228134' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10228134' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10498792' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10498792' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10569922' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10569922' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10638320' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10638320' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10649008' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10649008' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10689780' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10689780' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt10895576' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10895576' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10926320' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10926320' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10023286' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10023286' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10037014' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10037014' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10042788' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10042788' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10051000' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10051000' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10062338' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10062338' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10077034' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10077034' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10308878' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10308878' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt10687116' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10687116' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt11873440' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11873440' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt12141112' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt12141112' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt12593682' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt12593682' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt12740760' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt12740760' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10028196' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10028196' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1792543' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1792543' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10083340' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10083340' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt3704428' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt3704428' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10192406' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10192406' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt10535522' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10535522' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10545696' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10545696' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10640346' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10640346' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10684644' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10684644' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10687220' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10687220' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10737918' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10737918' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10789216' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10789216' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10811166' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10811166' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10865174' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10865174' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10931784' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10931784' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10949122' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10949122' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt11013696' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11013696' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11018264' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11018264' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11112808' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11112808' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt11278608' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11278608' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt11364112' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11364112' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt11939970' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11939970' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt16428782' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt16428782' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt8005118' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt8005118' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11319074' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11319074' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt14160834' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt14160834' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt14223946' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt14223946' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt14472156' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt14472156' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt15021154' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt15021154' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt15673502' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt15673502' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt21065476' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt21065476' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt23461428' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt23461428' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt23747498' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt23747498' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt1403987' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1403987' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1407084' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1407084' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1414378' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1414378' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt1453245' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1453245' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt1468703' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1468703' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1470023' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1470023' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1479398' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1479398' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1514054' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1514054' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt1336619' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1336619' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt1320296' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1320296' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt0800054' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0800054' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt1001526' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1001526' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0429493' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0429493' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt0477080' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0477080' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0480255' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0480255' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0800320' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0800320' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0914823' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0914823' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0938283' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0938283' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0944835' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0944835' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt1032751' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1032751' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1037705' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1037705' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1038686' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1038686' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt1053424' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1053424' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1075747' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1075747' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt0493949' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0493949' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0758752' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0758752' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0775543' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0775543' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0780653' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0780653' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0798817' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0798817' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0817177' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0817177' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt0840361' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0840361' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0889573' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0889573' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0892318' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0892318' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0896872' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0896872' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0902247' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0902247' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11866324' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11866324' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0935075' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0935075' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0947798' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0947798' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0954947' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0954947' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt2363363' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt2363363' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0964517' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0964517' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0968264' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0968264' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0970926' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0970926' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0977855' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0977855' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0984210' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0984210' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0997152' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0997152' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0409847' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0409847' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt0472399' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0472399' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0479997' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0479997' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0800369' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0800369' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0816462' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0816462' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0822847' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0822847' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0873886' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0873886' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0978764' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0978764' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt1034389' for key 'peliculas_caracteristicas.PRIMARY'
# ...
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt0478304' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0478304' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt0490847' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0490847' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0780504' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0780504' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0795459' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0795459' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0847180' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0847180' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0881320' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0881320' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0893412' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0893412' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0970179' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0970179' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0993842' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0993842' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0401729' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0401729' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0790724' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0790724' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt1059836' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1059836' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1074638' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1074638' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt1194173' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1194173' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1232829' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1232829' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1234719' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1234719' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt0383010' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0383010' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt0837562' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0837562' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0851471' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0851471' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0337692' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0337692' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0454876' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0454876' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0485985' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0485985' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0481499' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0481499' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt0996664' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0996664' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0932667' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0932667' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt0360556' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt0360556' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10534500' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10534500' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10644372' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10644372' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10061680' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10061680' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11375842' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11375842' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11696276' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11696276' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt11783766' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11783766' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt11947158' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt11947158' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10064664' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10064664' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt13130760' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt13130760' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1465477' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1465477' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt2409300' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt2409300' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt1116184' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1116184' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt1155076' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1155076' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt1181795' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt1181795' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10127464' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10127464' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10152736' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10152736' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10230994' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10230994' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10268316' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10268316' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10280296' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10280296' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10310074' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10310074' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10309902' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10309902' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10314548' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10314548' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10367074' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10367074' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10366514' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10366514' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10368680' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10368680' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10380900' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10380900' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10381014' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10381014' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1406 (22001): Data too long for column 'Nombre' at row 1
# Error Code: 1406
# SQLSTATE 22001
# Message Data too long for column 'Nombre' at row 1
# Error: 1062 (23000): Duplicate entry 'tt10422498' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10422498' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error Code: 1054
# SQLSTATE 42S22
# Message Unknown column 'nan' in 'field list'
# Error: 1062 (23000): Duplicate entry 'tt10514056' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10514056' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10510280' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10510280' for key 'peliculas_caracteristicas.PRIMARY'
# Error: 1062 (23000): Duplicate entry 'tt10521244' for key 'peliculas_caracteristicas.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'tt10521244' for key 'peliculas_caracteristicas.PRIMARY'
# Se han insertado los datos correctamente

# %% [markdown]
# ## Insertamos datos tabla Actores

# %%
#leemos el csv

df_actores = pd.read_csv("resultados_completos_F3_laura.csv", index_col = 0)  #cambiar el nombre del archivo

#Hacemos una lista con el nombre de las columnas actuales del data frame
columnas_actuales = df_actores.columns.tolist()

#Definimos el nombre de las columnas
nuevos_nombres = ['Nombre', 'AnioNacimiento', 'ConocidoPor', 'ActividadActual', 'Premios']

#Cambiamos el nombre de las columnas por la lista que hemos creado
df_actores.columns = nuevos_nombres

#Eliminamos duplicados 
df_actores = df_actores.drop_duplicates()

# %%
df_actores
# Out:
#                  Nombre  AnioNacimiento  \
# 0     Robert Downey Jr.            1965
# 1       Gwyneth Paltrow            1972
# 2           Don Cheadle            1964
# 3    Scarlett Johansson            1984
# 4          Sam Rockwell            1968
# ..                  ...             ...
# 268     Pankaj Tripathi            1976
# 269         Prem Chopra            1935
# 270    Govardhan Asrani            1941
# 271      Yashpal Sharma            1967
# 272         Rajiv Gupta            1967
#
#                                            ConocidoPor  \
# 0    ['Iron Man', 'Iron Man 3', 'Sherlock Holmes', ...
# 1    ['Shakespeare in Love (Shakespeare enamorado)'...
# 2    ['Crash (Colisión)', 'El irlandés', 'Hotel Rwa...
# 3    ['Lost in Translation', 'Her', 'Los Vengadores...
# 4    ['Moon', 'Tres anuncios en las afueras', 'Conf...
# ..                                                 ...
# 268  ['Gangs of Wasseypur', 'Stree', 'Gunjan Saxena...
# 269  ['Koi... Mil Gaya', 'Do Anjaane', 'Animal', 'G...
# 270  ['Bodyguard', 'Sholay', 'Chala Murari Hero Ban...
# 271  ['Lagaan: Érase una vez en la India', 'Neeli C...
# 272  ['Paan Singh Tomar', 'PK', 'La boda del monzón...
#
#                             ActividadActual  \
# 0        ['Reparto', 'Producción', 'Guion']
# 1    ['Reparto', 'Producción', 'Dirección']
# 2    ['Reparto', 'Producción', 'Dirección']
# 3    ['Reparto', 'Producción', 'Dirección']
# 4    ['Reparto', 'Producción', 'Dirección']
# ..                                      ...
# 268                             ['Reparto']
# 269                   ['Reparto', 'Música']
# 270  ['Reparto', 'Dirección', 'Producción']
# 271  ['Reparto', 'Producción', 'Dirección']
# 272                             ['Reparto']
#
#                                                Premios
# 0    ['Academy Awards USA Gan', 'Academy of Science...
# 1    ['Academy Awards USA Gan', 'Academy of Science...
# 2    ['Academy Awards USA Nom', 'Berlin Internation...
# 3    ['Academy Awards USA Nom', 'Academy of Science...
# 4    ['Academy Awards USA Nom', 'Academy of Science...
# ..                                                 ...
# 268  ['Filmfare Awards Nom', 'Awards of the Interna...
# 269  ['Filmfare Awards Gan', 'Screen Awards IN Gan'...
# 270  ['Filmfare Awards Nom', "People's Choice Award...
# 271  ['Filmfare Awards Nom', 'Awards of the Interna...
# 272  ['Screen Awards IN Nom', 'Contribuir a esta pá...
#
# [271 rows x 5 columns]

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='moviemakers')
mycursor = cnx.cursor()



#Iteramos por cada uno de los elementos

for index, row in df_actores.iterrows():           
    sql = """
        INSERT INTO actores (Nombre, AnioNacimiento, ConocidoPor, ActividadActual, Premios) 
        VALUES ( %s, %s, %s, %s, %s)
    """
    values = (row['Nombre'], row['AnioNacimiento'], row['ConocidoPor'], row['ActividadActual'], row['Premios'])
    
    try:
        mycursor.execute(sql, values)
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# Confirmar la inserción
cnx.commit()

print(f'Se han insertado los datos correctamente')
# Cerrar conexión
mycursor.close()
cnx.close()
# Out:
# Error: 1062 (23000): Duplicate entry 'Tom Holland' for key 'actores.PRIMARY'
# Error Code: 1062
# SQLSTATE 23000
# Message Duplicate entry 'Tom Holland' for key 'actores.PRIMARY'
# Se han insertado los datos correctamente

# %% [markdown]
# ## Insertamos datos tabla Actuaciones

# %%
#leemos el csv

df_actuaciones = pd.read_csv("tuplas_tabla_intermedia_F3_laura.csv", index_col = 0)  #cambiar el nombre del archivo

#Hacemos una lista con el nombre de las columnas actuales del data frame
columnas_actuales = df_actuaciones.columns.tolist()

#Definimos el nombre de las columnas
nuevos_nombres = ['IdPelicula', 'NombreActor']

#Cambiamos el nombre de las columnas por la lista que hemos creado
df_actuaciones.columns = nuevos_nombres

#Eliminamos duplicados 
df_actuaciones = df_actuaciones.drop_duplicates()

# %%
df_actuaciones
# Out:
#      IdPelicula         NombreActor
# 0     tt1228705   Robert Downey Jr.
# 1     tt1228705     Gwyneth Paltrow
# 2     tt1228705         Don Cheadle
# 3     tt1228705  Scarlett Johansson
# 4     tt1228705        Sam Rockwell
# ..          ...                 ...
# 405  tt10569922         Prem Chopra
# 406  tt10569922    Govardhan Asrani
# 407  tt10569922      Yashpal Sharma
# 408  tt10569922      Brijendra Kala
# 409  tt10569922         Rajiv Gupta
#
# [410 rows x 2 columns]

# %%
# Conectar a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='moviemakers')
mycursor = cnx.cursor()



#Iteramos por cada uno de los elementos

for index, row in df_actuaciones.iterrows():           
    sql = """
        INSERT INTO actuaciones (IdPelicula, NombreActor) 
        VALUES ( %s, %s)
    """
    values = (row['IdPelicula'], row['NombreActor'])
    
    try:
        mycursor.execute(sql, values)
    except mysql.connector.Error as err:
        print(f"Error: {err}")
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# Confirmar la inserción
cnx.commit()

print(f'Se han insertado los datos correctamente')
# Cerrar conexión
mycursor.close()
cnx.close()
# Out:
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Error Code: 1452
# SQLSTATE 23000
# Message Cannot add or update a child row: a foreign key constraint fails (`moviemakers`.`actuaciones`, CONSTRAINT `actuaciones_ibfk_2` FOREIGN KEY (`NombreActor`) REFERENCES `actores` (`Nombre`))
# Se han insertado los datos correctamente
